# %% [markdown]
# # Performance-level analysis
#
# Now that we have shown that rotations could influence the feature values in the previous phase of the study, more significant so on wavelet-based features, we want to know if this influence translate to model performance.
#
# Therefore, in this part of the study, we train models using $R_0$ features, selected from 1) WD-based features only $X_{WD}$; and 2) non-WD-based features only $X_{nWD}$, note that:
# $$
# \begin{align*}
# X_{WD} \cap X_{nWD} &= \emptyset \\
# X_{WD} \cup X_{nWD} &= X
# \end{align*}
# $$
#
# For the data at hand, the NSCLC lesions were classified into 4 subtypes including large cell (LCC), adenocarcinoma (ACC), squamous cell carcinoma (SCC), and not otherwise specified (nos). There are also some cases with no available information labelled as NA. In this study, we exclude both patients with nos and NA. See manuscript for more information.
#
# ## Study design
#
# ![Study design](./img/study_design.png)
#
# ## Reference
#
# Manuscript in preparation:
#
# >    *Decoding the Rotation Effect: A Retrospective Study on Lesion Orientation and Wavelet Decomposition in Radiomics*
#
# # Usage
#
# This notebook runs on the features extracted using the script provided. The features were stored as a HDF data store in `../data/RadFeatures_raw_fine_res.h5`. For the data structure, please see [`1_features_analysis.ipynb`](./1_feature_analysis.ipynb)
#
# For more details, please see [README](./README.md)
#
# ## Radiomics pipeline

# %%
import pandas as pd
import scipy 
import numpy as np
import SimpleITK as sitk
import os, sys
import mri_radiomics_toolkit as mradtk
import itertools
import sklearn.utils as skutils
import sklearn.linear_model as linear_model
import tqdm.auto
import joblib
import warnings
from IPython.display import *
from pathlib import Path
from mnts.mnts_logger import MNTSLogger
from typing import Tuple, Union, Iterable, Any, Optional
from tqdm import auto
from sklearn import pipeline
from functools import partial
np.warnings = warnings # work arround 


# define for easy usage
mdprint = lambda x: display(Markdown(x))

# add package to path without installing it
sys.path.append(Path(".").absolute().__str__())

# List out the version of the packages required
np_ver = np.__version__
sp_ver = scipy.__version__
sitk_ver = sitk.__version__
pd_ver = pd.__version__
display({
    'Numpy version': np_ver, 
    'Scipy version': sp_ver, 
    'SITK version': sitk_ver,
    'Pandas version': pd_ver
})

'''Configurations'''
MNTSLogger.set_global_log_level('debug')
os.chdir('/media/storage/Source/Repos/wavelet_analysis/src')
src_root = Path(".")
resource_root = src_root / "resources"
data_root = Path("../data")
idregpat = "^([\w\d]+-\d+)" # For pairing the IDs
clinical = data_root.joinpath("NSCLC-clinical-Oct 2019.csv")
clinical_df = pd.read_csv(clinical, index_col=0)
radiomics_data_path = data_root / "RadFeatures_raw_fine_res.h5"

# exclude list
exclude_pids = [
    'LUNG1-128', # Cannot load
    'LUNG1-246', # Canoot load
]

clinical_df.drop(exclude_pids, inplace=True)
display(clinical_df)
# Out:
# {'Numpy version': '1.24.3',
#  'Scipy version': '1.10.1',
#  'SITK version': '2.2.1',
#  'Pandas version': '2.0.1'}
# [2024-02-24 04:38:09,358-INFO] (global) Setting log level info -> debug
# [2024-02-24 04:38:09,359-INFO] (preliminary_feature_filtering) Setting log level info -> debug
# [2024-02-24 04:38:09,359-INFO] (ANOVA) Setting log level info -> debug
# [2024-02-24 04:38:09,360-INFO] (sup-featselect) Setting log level info -> debug
# [2024-02-24 04:38:09,360-INFO] (model-building) Setting log level info -> debug
#                age  clinical.T.Stage  Clinical.N.Stage  Clinical.M.Stage
# PatientID
# LUNG1-001  78.7515               2.0                 3                 0  \
# LUNG1-002  83.8001               2.0                 0                 0
# LUNG1-003  68.1807               2.0                 3                 0
# LUNG1-004  70.8802               2.0                 1                 0
# LUNG1-005  80.4819               4.0                 2                 0
# ...            ...               ...               ...               ...
# LUNG1-418  53.6712               2.0                 0                 0
# LUNG1-419  66.5096               4.0                 1                 0
# LUNG1-420  73.3808               2.0                 1                 0
# LUNG1-421  61.7041               2.0                 2                 0
# LUNG1-422  68.1260               2.0                 0                 0
#
#           Overall.Stage                Histology  gender  Survival.time
# PatientID
# LUNG1-001          IIIb               large cell    male           2165  \
# LUNG1-002             I  squamous cell carcinoma    male            155
# LUNG1-003          IIIb               large cell    male            256
# LUNG1-004            II  squamous cell carcinoma    male            141
# LUNG1-005          IIIb  squamous cell carcinoma    male            353
# ...                 ...                      ...     ...            ...
# LUNG1-418             I           adenocarcinoma    male            346
# LUNG1-419          IIIb  squamous cell carcinoma    male           2772
# LUNG1-420            II  squamous cell carcinoma    male           2429
# LUNG1-421          IIIa  squamous cell carcinoma  female            369
# LUNG1-422             I                      NaN  female           1590
#
#            deadstatus.event
# PatientID
# LUNG1-001                 1
# LUNG1-002                 1
# LUNG1-003                 1
# LUNG1-004                 1
# LUNG1-005                 1
# ...                     ...
# LUNG1-418                 1
# LUNG1-419                 0
# LUNG1-420                 1
# LUNG1-421                 1
# LUNG1-422                 1
#
# [420 rows x 9 columns]

# %% [markdown]
# # Patient characteristics

# %%
mdprint("## For all patients")
mdprint("### Summary characteristics")
display(clinical_df.describe())

# sumamrize stages information
stages_df = pd.concat([clinical_df['clinical.T.Stage'].value_counts(),
                       clinical_df['Clinical.N.Stage'].value_counts(),
                       clinical_df['Clinical.M.Stage'].value_counts()], axis=1)
stages_df.columns = ['T', 'N', 'M']
stages_df.index = stages_df.index.astype('int')
stages_df.sort_index(inplace=True)

mdprint("### Stages distribution")
display(stages_df.fillna(0))

# summarize histology
mdprint("## For patients with histology")
mdprint("### Summary of histology")
hist_df = clinical_df['Histology'].value_counts(dropna=False)
display(hist_df.to_frame())

# get the list of patients with histology
clinical_df_whist = clinical_df.loc[clinical_df['Histology'] != 'nos'].copy()['Histology'].to_frame()
clinical_df_whist.dropna(inplace=True)
mdprint("### Summary characteristics")
display(clinical_df_whist['Histology'].value_counts(dropna=False))
# Out:
# ## For all patients
# ### Summary characteristics
#               age  clinical.T.Stage  Clinical.N.Stage  Clinical.M.Stage
# count  398.000000         419.00000        420.000000        420.000000  \
# mean    68.094625           2.47494          1.352381          0.030952
# std     10.058821           1.13290          1.218246          0.295542
# min     33.684900           1.00000          0.000000          0.000000
# 25%     61.301200           2.00000          0.000000          0.000000
# 50%     68.713700           2.00000          2.000000          0.000000
# 75%     75.887025           4.00000          2.000000          0.000000
# max     91.704300           5.00000          4.000000          3.000000
#
#        Survival.time  deadstatus.event
# count     420.000000        420.000000
# mean      984.385714          0.888095
# std      1030.134266          0.315625
# min        10.000000          0.000000
# 25%       260.250000          1.000000
# 50%       545.500000          1.000000
# 75%      1393.000000          1.000000
# max      4454.000000          1.000000
# ### Stages distribution
#        T      N      M
# 0    0.0  170.0  415.0
# 1   93.0   22.0    1.0
# 2  155.0  141.0    0.0
# 3   52.0   84.0    4.0
# 4  117.0    3.0    0.0
# 5    2.0    0.0    0.0
# ## For patients with histology
# ### Summary of histology
#                          count
# Histology
# squamous cell carcinoma    152
# large cell                 114
# nos                         62
# adenocarcinoma              51
# NaN                         41
# ### Summary characteristics
# Histology
# squamous cell carcinoma    152
# large cell                 114
# adenocarcinoma              51
# Name: count, dtype: int64

# %% [markdown]
# # Load the radiomics features

# %%
from feature_robustness_analysis.io import standardize_df

# Load the features
features_df = pd.read_hdf(radiomics_data_path)
features_df = standardize_df(features_df.T).drop('diagnostics')

# Extract the data that has histology
X_all = features_df[clinical_df_whist.index]
display(X_all)
# Out:
# PID                                             LUNG1-001
# LessionCode
# Rotation                                              R00        R10
# ImagingFilter Category Name
# original      shape    Elongation                0.727227   0.727191  \
#                        Flatness                  0.545216   0.544209
#                        LeastAxisLength          45.743563  45.623419
#                        MajorAxisLength          83.899907  83.834408
#                        Maximum2DDiameterColumn  93.932927   91.57324
# ...                                                   ...        ...
# logarithm     ngtdm    Busyness                 45.928779  45.625421
#                        Coarseness                0.000078   0.000078
#                        Complexity               45.426285  44.946281
#                        Contrast                  0.011986   0.011613
#                        Strength                  0.018017   0.018257
#
# PID
# LessionCode
# Rotation                                              R15        R20
# ImagingFilter Category Name
# original      shape    Elongation                0.726599   0.727014  \
#                        Flatness                  0.544994   0.544926
#                        LeastAxisLength          45.692782  45.679115
#                        MajorAxisLength          83.840833  83.826295
#                        Maximum2DDiameterColumn  93.998896  88.915466
# ...                                                   ...        ...
# logarithm     ngtdm    Busyness                 45.470045  44.903059
#                        Coarseness                0.000078   0.000079
#                        Complexity               44.629187  44.638569
#                        Contrast                  0.011569   0.011789
#                        Strength                  0.018395   0.018357
#
# PID
# LessionCode
# Rotation                                              R25        R30
# ImagingFilter Category Name
# original      shape    Elongation                0.727373   0.727265  \
#                        Flatness                  0.545092   0.545003
#                        LeastAxisLength          45.680463    45.6729
#                        MajorAxisLength          83.803233  83.802969
#                        Maximum2DDiameterColumn  92.216668  90.272626
# ...                                                   ...        ...
# logarithm     ngtdm    Busyness                 44.483675  45.160686
#                        Coarseness                 0.00008   0.000079
#                        Complexity               44.209293  44.616998
#                        Contrast                  0.011729   0.011723
#                        Strength                  0.018541   0.018381
#
# PID
# LessionCode
# Rotation                                              R35        R40
# ImagingFilter Category Name
# original      shape    Elongation                 0.72736   0.726967  \
#                        Flatness                  0.545036   0.544964
#                        LeastAxisLength          45.666421  45.673603
#                        MajorAxisLength          83.786089  83.810238
#                        Maximum2DDiameterColumn  93.393283  81.266196
# ...                                                   ...        ...
# logarithm     ngtdm    Busyness                 44.200094  45.096904
#                        Coarseness                 0.00008   0.000079
#                        Complexity               43.964332  44.640065
#                        Contrast                  0.011758   0.011683
#                        Strength                  0.018656    0.01838
#
# PID                                                                   ...
# LessionCode                                                           ...
# Rotation                                              R45        R05  ...
# ImagingFilter Category Name                                           ...
# original      shape    Elongation                0.727177   0.726972  ...  \
#                        Flatness                  0.545055   0.544997  ...
#                        LeastAxisLength          45.674558  45.680083  ...
#                        MajorAxisLength          83.798134  83.817069  ...
#                        Maximum2DDiameterColumn  80.683213  93.831345  ...
# ...                                                   ...        ...  ...
# logarithm     ngtdm    Busyness                 45.060095   45.08508  ...
#                        Coarseness                0.000079   0.000079  ...
#                        Complexity               44.531808  44.592335  ...
#                        Contrast                  0.011661    0.01171  ...
#                        Strength                  0.018422   0.018394  ...
#
# PID                                             LUNG1-421
# LessionCode
# Rotation                                              R40        R45
# ImagingFilter Category Name
# original      shape    Elongation                0.776835   0.777889  \
#                        Flatness                   0.64158   0.641207
#                        LeastAxisLength          32.729696  32.711779
#                        MajorAxisLength          51.014199   51.01595
#                        Maximum2DDiameterColumn  60.829732  49.110512
# ...                                                   ...        ...
# logarithm     ngtdm    Busyness                 25.992902  84.892336
#                        Coarseness                0.000314   0.000232
#                        Complexity               14.883252   8.759975
#                        Contrast                  0.025759   0.034133
#                        Strength                  0.026045   0.008228
#
# PID
# LessionCode
# Rotation                                              R05        R50
# ImagingFilter Category Name
# original      shape    Elongation                0.776214   0.776608  \
#                        Flatness                  0.638647    0.64071
#                        LeastAxisLength          32.624467  32.707135
#                        MajorAxisLength           51.08376  51.048268
#                        Maximum2DDiameterColumn  56.892624   49.89078
# ...                                                   ...        ...
# logarithm     ngtdm    Busyness                 21.900443  31.159373
#                        Coarseness                0.000355   0.000381
#                        Complexity               11.874364   7.385874
#                        Contrast                  0.017177   0.024017
#                        Strength                  0.031116   0.020881
#
# PID
# LessionCode
# Rotation                                              R55        R60
# ImagingFilter Category Name
# original      shape    Elongation                0.775722   0.776907  \
#                        Flatness                   0.64095   0.641733
#                        LeastAxisLength           32.71242  32.734819
#                        MajorAxisLength          51.037436  51.010049
#                        Maximum2DDiameterColumn  65.012957  58.218198
# ...                                                   ...        ...
# logarithm     ngtdm    Busyness                 27.268277  26.907348
#                        Coarseness                  0.0003   0.000372
#                        Complexity               15.791292   8.908219
#                        Contrast                  0.027496   0.020257
#                        Strength                  0.025125   0.022285
#
# PID
# LessionCode
# Rotation                                              R65        R70
# ImagingFilter Category Name
# original      shape    Elongation                0.778633   0.776914  \
#                        Flatness                  0.642394   0.640914
#                        LeastAxisLength          32.734656  32.710618
#                        MajorAxisLength          50.957259  51.037448
#                        Maximum2DDiameterColumn  48.573555   54.90505
# ...                                                   ...        ...
# logarithm     ngtdm    Busyness                 24.824137  31.296444
#                        Coarseness                0.000328   0.000375
#                        Complexity               13.773907   7.240072
#                        Contrast                  0.023956   0.025214
#                        Strength                  0.026874   0.021073
#
# PID
# LessionCode
# Rotation                                              R75        R80
# ImagingFilter Category Name
# original      shape    Elongation                0.779277   0.776845
#                        Flatness                  0.642063   0.641025
#                        LeastAxisLength          32.705374  32.716974
#                        MajorAxisLength          50.937962  51.038495
#                        Maximum2DDiameterColumn   60.55475  60.931553
# ...                                                   ...        ...
# logarithm     ngtdm    Busyness                 24.028008  85.112309
#                        Coarseness                0.000336   0.000229
#                        Complexity               13.051764   8.806948
#                        Contrast                  0.022269   0.033644
#                        Strength                  0.027802    0.00809
#
# [1688 rows x 5950 columns]

# %% [markdown]
# ## Handling patients with multiple segmentations
#
# There are a few dozens of patients with multiple segmentations. Some of them were already filtered away in phase 1 of the study, but there still are still a few left. Because the original histology information provided by Aerts et al. did not specify the site of biopsy or histology specimen, cases with individually segmented, discontinued masses, we cannot say for sure they share the same histology. Therefore, we inspect each of the cases and filter out those that have segmentation on the both sides of the lung, which has the highest probability of having different histology.

# %%
#! secondary drop list for removing human errors and uncertain histology
# exclude list
exclude_pids = [
    'LUNG1-019', # Erroroneous segmentation
    'LUNG1-326', # both side tumors
    'LUNG1-353', # both side tumors
    'LUNG1-372', # both side tumors
    'LUNG1-399', # both side tumors
]


# * check if any of them are still in the dataset with histology available
curr_patients = X_all.columns.get_level_values(0).unique()
secondary_exclude = pd.Series({k: k in curr_patients for k in exclude_pids})
display(secondary_exclude.to_frame())
mdprint(f"> Note: {sum(secondary_exclude)} more patients were excluded.")

# * exclude all these cases if they are in the feature list
X_all.drop(exclude_pids, level=0, axis=1, inplace=True)

# # * finally only look at the largest lesion
volumes = X_all.T.query("LessionCode != 'A' and LessionCode != ''")
X_all = X_all.drop(volumes.index, axis=1)
display(X_all.columns.get_level_values(0).unique())
# Out:
#                0
# LUNG1-019  False
# LUNG1-326   True
# LUNG1-353  False
# LUNG1-372   True
# LUNG1-399   True
# > Note: 3 more patients were excluded.
# Index(['LUNG1-001', 'LUNG1-002', 'LUNG1-003', 'LUNG1-004', 'LUNG1-005',
#        'LUNG1-006', 'LUNG1-007', 'LUNG1-008', 'LUNG1-009', 'LUNG1-010',
#        ...
#        'LUNG1-412', 'LUNG1-413', 'LUNG1-414', 'LUNG1-415', 'LUNG1-416',
#        'LUNG1-417', 'LUNG1-418', 'LUNG1-419', 'LUNG1-420', 'LUNG1-421'],
#       dtype='object', name='PID', length=314)

# %% [markdown]
# # Radiomics Pipeline
#
# ## Segregating the data
#
# We are looking at:
# 1. Only WD features ($X_{WD}$)
# 2. Only non-WD features ($X_{nWD}$)

# %% [markdown]
# ## Variable explanations
#
# | Variable     | Description                                                                 |
# |--------------|-----------------------------------------------------------------------------|
# | `y`          | Ground-truth label of histology                                             |
# | `y_onehot`   | One-hot version of `y`                                                      |
# | `X_all`      | Radiomics features                                                          |
# | `X_all_R0`   | Radiomics features of R0 samples only, meaning no rotations were applied.   |
# | `X_WD`       | Radiomics features from WD filters only                                     |
# | `X_nWD`      | Radiomics features from non-WD filters only, excludes shape features        |

# %%
# getting WD only features
wd_names = [f'wavelet-{"".join(x)}' for x in itertools.product(*([('H', 'L')] * 3))]
X_WD = X_all.loc[wd_names]
mdprint("### WD only features ($X_{WD}$)")
display(X_WD)

# getting non-WD only features
X_nWD = X_all.loc[features_df.index._get_level_values(0).difference(wd_names)]
X_nWD.drop('shape', axis=0, level=1, inplace=True) # Exclude shape features
mdprint("### non-WD only features ($X_{nWD}$)")
display(X_nWD)

mdprint("### Number of Cases")
display(len(X_all.columns.get_level_values(0).unique()))
# Out:
# ### WD only features ($X_{WD}$)
# PID                                           LUNG1-001
# LessionCode
# Rotation                                            R00         R10
# ImagingFilter Category   Name
# wavelet-HHH   firstorder 10Percentile         -0.006612   -0.006196  \
#                          90Percentile           0.00661    0.006206
#                          Energy                5.289175    4.731673
#                          Entropy               0.999999    0.999994
#                          InterquartileRange    0.006416    0.006034
# ...                                                 ...         ...
# wavelet-LLL   ngtdm      Busyness             12.206095   12.084919
#                          Coarseness            0.000074    0.000075
#                          Complexity          268.600376  266.508771
#                          Contrast              0.007902     0.00778
#                          Strength              0.105865    0.106865
#
# PID
# LessionCode
# Rotation                                            R15         R20
# ImagingFilter Category   Name
# wavelet-HHH   firstorder 10Percentile         -0.013886   -0.006577  \
#                          90Percentile          0.013969     0.00655
#                          Energy               21.671994    5.352313
#                          Entropy                    1.0    0.999998
#                          InterquartileRange    0.014099    0.006432
# ...                                                 ...         ...
# wavelet-LLL   ngtdm      Busyness             12.210817   12.106545
#                          Coarseness            0.000074    0.000075
#                          Complexity          267.322944  269.083699
#                          Contrast              0.007823    0.007841
#                          Strength              0.106528    0.108387
#
# PID
# LessionCode
# Rotation                                            R25         R30
# ImagingFilter Category   Name
# wavelet-HHH   firstorder 10Percentile          -0.01325   -0.008982  \
#                          90Percentile          0.013243    0.008964
#                          Energy               19.912227    9.243655
#                          Entropy               0.999999         1.0
#                          InterquartileRange    0.013452    0.009105
# ...                                                 ...         ...
# wavelet-LLL   ngtdm      Busyness             13.302507   12.138941
#                          Coarseness            0.000074    0.000074
#                          Complexity          254.001143  266.886398
#                          Contrast              0.008292    0.007813
#                          Strength              0.098354    0.106713
#
# PID
# LessionCode
# Rotation                                            R35         R40
# ImagingFilter Category   Name
# wavelet-HHH   firstorder 10Percentile         -0.013165   -0.012083  \
#                          90Percentile          0.013173    0.012032
#                          Energy                19.57019   18.155947
#                          Entropy                    1.0    0.999994
#                          InterquartileRange    0.013432    0.011901
# ...                                                 ...         ...
# wavelet-LLL   ngtdm      Busyness             12.606074   12.131731
#                          Coarseness            0.000074    0.000074
#                          Complexity          253.146454  268.091613
#                          Contrast              0.008292    0.007808
#                          Strength               0.10116    0.107545
#
# PID                                                                  ...
# LessionCode                                                          ...
# Rotation                                            R45         R05  ...
# ImagingFilter Category   Name                                        ...
# wavelet-HHH   firstorder 10Percentile         -0.012539   -0.008109  ...  \
#                          90Percentile          0.012501    0.008119  ...
#                          Energy               19.487921    7.513284  ...
#                          Entropy               0.999999    0.999999  ...
#                          InterquartileRange    0.012461    0.008212  ...
# ...                                                 ...         ...  ...
# wavelet-LLL   ngtdm      Busyness              12.14532   12.122981  ...
#                          Coarseness            0.000074    0.000074  ...
#                          Complexity          266.979944  268.486217  ...
#                          Contrast              0.007804    0.007801  ...
#                          Strength              0.106687    0.108623  ...
#
# PID                                          LUNG1-421
# LessionCode
# Rotation                                           R40        R45        R05
# ImagingFilter Category   Name
# wavelet-HHH   firstorder 10Percentile        -0.008625   -0.00945  -0.004487  \
#                          90Percentile         0.008604   0.009448   0.004355
#                          Energy               2.947578   3.422126   0.765366
#                          Entropy                   1.0        1.0   0.999969
#                          InterquartileRange   0.007888   0.008973   0.003965
# ...                                                ...        ...        ...
# wavelet-LLL   ngtdm      Busyness             7.967374   7.997804   8.006495
#                          Coarseness           0.000288   0.000287   0.000287
#                          Complexity          77.895082  78.169391  79.025926
#                          Contrast             0.026512   0.026585   0.026521
#                          Strength             0.122584   0.122047   0.120551
#
# PID
# LessionCode
# Rotation                                          R50        R55        R60
# ImagingFilter Category   Name
# wavelet-HHH   firstorder 10Percentile        -0.00885  -0.008706  -0.007158  \
#                          90Percentile        0.008731   0.008656   0.007076
#                          Energy              2.859875   3.048037   1.898348
#                          Entropy             0.999994   0.999999   0.999993
#                          InterquartileRange  0.008322   0.008156   0.006803
# ...                                               ...        ...        ...
# wavelet-LLL   ngtdm      Busyness            8.022501   7.982128   7.968822
#                          Coarseness          0.000286   0.000288   0.000288
#                          Complexity          78.63185  78.055036  78.521336
#                          Contrast            0.026654   0.026667   0.026883
#                          Strength            0.121357   0.122033   0.120919
#
# PID
# LessionCode
# Rotation                                           R65        R70        R75
# ImagingFilter Category   Name
# wavelet-HHH   firstorder 10Percentile        -0.008265  -0.007802  -0.004764  \
#                          90Percentile         0.008173   0.007675   0.004637
#                          Energy               2.498022   2.079198   0.816922
#                          Entropy              0.999999   0.999993   0.999983
#                          InterquartileRange   0.007883   0.007461   0.004327
# ...                                                ...        ...        ...
# wavelet-LLL   ngtdm      Busyness             7.950204   8.014583   8.001931
#                          Coarseness           0.000289   0.000287   0.000287
#                          Complexity          78.488515  79.007824  78.783269
#                          Contrast             0.026849   0.026886   0.026393
#                          Strength             0.120863   0.120522   0.121658
#
# PID
# LessionCode
# Rotation                                           R80
# ImagingFilter Category   Name
# wavelet-HHH   firstorder 10Percentile        -0.006709
#                          90Percentile         0.006633
#                          Energy               1.706881
#                          Entropy              0.999991
#                          InterquartileRange   0.006256
# ...                                                ...
# wavelet-LLL   ngtdm      Busyness             7.975322
#                          Coarseness           0.000288
#                          Complexity          78.415622
#                          Contrast              0.02654
#                          Strength             0.121802
#
# [744 rows x 5338 columns]
# ### non-WD only features ($X_{nWD}$)
# PID                                              LUNG1-001
# LessionCode
# Rotation                                               R00            R10
# ImagingFilter Category   Name
# exponential   firstorder 10Percentile             0.845402       0.846659  \
#                          90Percentile             1.217135       1.218058
#                          Energy              207278.584093  207214.460545
#                          Entropy                  0.721847       0.721132
#                          InterquartileRange       0.091773       0.091441
# ...                                                    ...            ...
# squareroot    ngtdm      Busyness                53.399118      53.872637
#                          Coarseness               0.000062       0.000062
#                          Complexity              62.567682      62.681291
#                          Contrast                 0.025009       0.024508
#                          Strength                 0.015239       0.015234
#
# PID
# LessionCode
# Rotation                                               R15            R20
# ImagingFilter Category   Name
# exponential   firstorder 10Percentile             0.845255       0.846421  \
#                          90Percentile             1.217956       1.216305
#                          Energy              207320.315036  206926.752697
#                          Entropy                  0.722075       0.719982
#                          InterquartileRange       0.091546       0.091008
# ...                                                    ...            ...
# squareroot    ngtdm      Busyness                53.726684      52.589216
#                          Coarseness               0.000062       0.000063
#                          Complexity              62.342269       61.82298
#                          Contrast                 0.024428       0.024707
#                          Strength                 0.015314       0.015447
#
# PID
# LessionCode
# Rotation                                               R25            R30
# ImagingFilter Category   Name
# exponential   firstorder 10Percentile             0.847258       0.847848  \
#                          90Percentile             1.215841       1.216766
#                          Energy              206813.382665  206966.821053
#                          Entropy                  0.720081       0.721796
#                          InterquartileRange       0.090921       0.091103
# ...                                                    ...            ...
# squareroot    ngtdm      Busyness                51.525783      52.707852
#                          Coarseness               0.000064       0.000063
#                          Complexity               60.94195      61.877806
#                          Contrast                 0.024492         0.0246
#                          Strength                 0.015684       0.015438
#
# PID
# LessionCode
# Rotation                                               R35            R40
# ImagingFilter Category   Name
# exponential   firstorder 10Percentile              0.84756       0.847367  \
#                          90Percentile             1.215064       1.216991
#                          Energy              206595.382453  207042.620621
#                          Entropy                   0.71849       0.719716
#                          InterquartileRange       0.090164       0.091291
# ...                                                    ...            ...
# squareroot    ngtdm      Busyness                50.912929      52.838895
#                          Coarseness               0.000065       0.000063
#                          Complexity              60.266377      61.966589
#                          Contrast                 0.024392       0.024522
#                          Strength                 0.015856       0.015421
#
# PID
# LessionCode
# Rotation                                               R45            R05
# ImagingFilter Category   Name
# exponential   firstorder 10Percentile             0.846483       0.846459  \
#                          90Percentile             1.217017       1.216774
#                          Energy              207059.677897  206989.601842
#                          Entropy                  0.719103       0.720305
#                          InterquartileRange       0.091231       0.091285
# ...                                                    ...            ...
# squareroot    ngtdm      Busyness                52.897289      52.682349
#                          Coarseness               0.000063       0.000063
#                          Complexity              61.806882      61.744362
#                          Contrast                 0.024478       0.024524
#                          Strength                 0.015462       0.015468
#
# PID                                          ...     LUNG1-421
# LessionCode                                  ...
# Rotation                                     ...           R40           R45
# ImagingFilter Category   Name                ...
# exponential   firstorder 10Percentile        ...      0.900503      0.898515  \
#                          90Percentile        ...      1.307269      1.313072
#                          Energy              ...  63979.477715  64449.067992
#                          Entropy             ...      0.610504      0.611646
#                          InterquartileRange  ...      0.136083      0.139877
# ...                                          ...           ...           ...
# squareroot    ngtdm      Busyness            ...      21.31336     45.291231
#                          Coarseness          ...      0.000296      0.000341
#                          Complexity          ...     20.183038      5.622871
#                          Contrast            ...      0.038687      0.035457
#                          Strength            ...      0.030792      0.013238
#
# PID
# LessionCode
# Rotation                                              R05           R50
# ImagingFilter Category   Name
# exponential   firstorder 10Percentile            0.896344      0.892309  \
#                          90Percentile            1.324495      1.336001
#                          Energy              65369.964399  66140.315023
#                          Entropy                 0.610186      0.613595
#                          InterquartileRange      0.142837      0.149687
# ...                                                   ...           ...
# squareroot    ngtdm      Busyness               22.931501     36.893394
#                          Coarseness              0.000317       0.00027
#                          Complexity             17.332919     11.354792
#                          Contrast                0.042239      0.031276
#                          Strength                 0.02859      0.017945
#
# PID
# LessionCode
# Rotation                                              R55           R60
# ImagingFilter Category   Name
# exponential   firstorder 10Percentile             0.89989      0.893221  \
#                          90Percentile            1.306099      1.331274
#                          Energy              63954.593498  65783.457254
#                          Entropy                 0.611709      0.613259
#                          InterquartileRange      0.136409      0.147705
# ...                                                   ...           ...
# squareroot    ngtdm      Busyness                22.03511     32.656496
#                          Coarseness              0.000286      0.000237
#                          Complexity             20.570032     22.757081
#                          Contrast                0.039809      0.045506
#                          Strength                0.030209      0.023116
#
# PID
# LessionCode
# Rotation                                              R65           R70
# ImagingFilter Category   Name
# exponential   firstorder 10Percentile            0.898307      0.893001  \
#                          90Percentile            1.309346      1.334103
#                          Energy              64173.677039  66034.270991
#                          Entropy                  0.61141      0.615349
#                          InterquartileRange      0.137651      0.149249
# ...                                                   ...           ...
# squareroot    ngtdm      Busyness               21.329294     52.065002
#                          Coarseness              0.000296        0.0002
#                          Complexity             20.527665     18.738581
#                          Contrast                0.038971      0.052508
#                          Strength                0.030203      0.014329
#
# PID
# LessionCode
# Rotation                                              R75           R80
# ImagingFilter Category   Name
# exponential   firstorder 10Percentile            0.902949      0.898655
#                          90Percentile            1.311155      1.311217
#                          Energy              64373.730666  64278.642993
#                          Entropy                 0.601304      0.609373
#                          InterquartileRange      0.137405      0.139024
# ...                                                   ...           ...
# squareroot    ngtdm      Busyness               21.107449     45.227866
#                          Coarseness              0.000298      0.000342
#                          Complexity              20.31667      5.633295
#                          Contrast                0.037549      0.035245
#                          Strength                0.030535      0.013217
#
# [930 rows x 5338 columns]
# ### Number of Cases
# 314

# %% [markdown]
# ## Steps for feature selection:
#
# ```mermaid
# flowchart TD
#     AD[("All Patients <br> (R_0 features)")]
#     T[("Training folds")]
#     H[("Testing fold")]
#     AD --> kfold[5-fold CV Splitter]
#     kfold --> |80%|T
#     kfold --> |20%|H
#     T ---> fine
# 	T --> training[Model Training]
#     AD --> |X_WD / X_nWD|pre(Preliminary feature selection)
#     pre --> |Surviving features|fine(Fine feature selection)
#     fine --> |Surviving features|training
#     H --> testing(Cross-validation)
#     training --> testing
#     testing --> res("5-fold results averaged")
# ```
#
# Note that this feature selection process does not include the testing pipeline
# ### 1. Preliminary feature selection
#
# Features are preliminarily filtered based on statistical requirement. First, `VarianceThreshold` is applied to remove features that are almost identical across all cases. Second, ANOVA was used to identified features that showed statistically significant mean differences across the three target classes.
#
# **This step was conducted prior to splitting the patients into folds.**
#
# ### 2. Fine feature selection
#
# Features were further selected using more sophisticated selection technique, namely Elastic net. The elastic net can be seen as a combination of LASSO and Ridge, which uses $L_1$ and $L_2$ regularization, respectively. Elastic net was used for each run within the K-fold iteration using only the training fold data. Therefore, each run would select a slightly different feature from either the $X_{WD}$ or $X_{nWD}$ group.
#
# **This step is conducted within the K-fold cross-validation iteration**

# %%
'''Preparatinos'''

from sklearn.preprocessing import *
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn import metrics, ensemble
from mri_radiomics_toolkit.utils import *
from mri_radiomics_toolkit.feature_selection import *
from mri_radiomics_toolkit.model_building import cv_grid_search, neg_log_loss
from mri_radiomics_toolkit.models.cards import multi_class_cv_grid_search_card
from mri_radiomics_toolkit.perf_metric import top_k_accuracy_score_
from functools import partial
import sklearn
import warnings
warnings.filterwarnings('ignore')

# * set logger level to show warning only
MNTSLogger.set_global_log_level('debug')

# * Code the classes into integers
label_map = {
    key:  i for i, key in enumerate(clinical_df_whist['Histology'].unique())
}
mdprint("## Mapping")
display(label_map)

# * Get the ground-truth
y = clinical_df_whist['Histology'].replace(label_map)

# * Get the R0 original features for training
X_all_R0 = X_all.reorder_levels(axis=1, order=[2, 0, 1])['R00']
X_WD_R0 = X_WD.reorder_levels(axis=1, order=[2, 0, 1])['R00']
X_nWD_R0 = X_nWD.reorder_levels(axis=1, order=[2, 0, 1])['R00']

# * Map y to match indices of X
y = y.loc[X_all_R0.columns.droplevel(1)]
y.index = X_all_R0.columns
# Convert y into one-hot vector
y_onehot = pd.get_dummies(y)

# * Sanity check
assert X_all_R0.T.index.identical(y_onehot.index), \
    f"Index is different: {X_all_R0.T.index.difference(y_onehot.index)}"

# * Rest of the features
rot_degs = [f'R{i:02d}' for i in range(0, 81, 5)]
rot_degs.remove('R00')
print(rot_degs)
X_all_rest = X_all.reorder_levels(axis=1, order=[2, 0, 1])[rot_degs]
X_WD_rest = X_WD.reorder_levels(axis=1, order=[2, 0, 1])[rot_degs]
X_nWD_rest = X_nWD.reorder_levels(axis=1, order=[2, 0, 1])[rot_degs]

# * Choose feature level normalizers
normalizer_cls = partial(StandardScaler)
# Out:
# [2024-02-24 04:38:15,036-INFO] (global) Setting log level info -> debug
# [2024-02-24 04:38:15,037-INFO] (preliminary_feature_filtering) Setting log level info -> debug
# [2024-02-24 04:38:15,037-INFO] (ANOVA) Setting log level info -> debug
# [2024-02-24 04:38:15,037-INFO] (sup-featselect) Setting log level info -> debug
# [2024-02-24 04:38:15,037-INFO] (model-building) Setting log level info -> debug
# ## Mapping
# {'large cell': 0, 'squamous cell carcinoma': 1, 'adenocarcinoma': 2}
# ['R05', 'R10', 'R15', 'R20', 'R25', 'R30', 'R35', 'R40', 'R45', 'R50', 'R55', 'R60', 'R65', 'R70', 'R75', 'R80']

# %% [markdown]
# ## Sanity check
#
# Now lets check if the feature normalization step is functioning properly. We based the normalization on $R_0$ features, and then apply it on $R_{05}$ to $R_{80}$ features to see how many of the features had its mean and variance shifted correctly.

# %%
# * Sanity check if Z-score is valid for all rotations 
normalizer = normalizer_cls()
X_all_zscored = normalizer.fit_transform(X_all_R0.T).T
X_all_zscored = pd.DataFrame(data=X_all_zscored, index=X_all_rest['R10'].index, columns=X_all_rest['R10'].columns)

# for each rotation
_t = []
for rot in rot_degs:
    # check how many features is not valid for the R0 mean/var
    _zscored = normalizer.transform(X_all_rest[rot].T).T
    _zscored = pd.DataFrame(_zscored, index=X_all_rest[rot].index, columns=X_all_rest[rot].columns)
    _zscored_mean = _zscored.mean(axis=1)
    _zscored_mean.name = 'Mean'
    _zscored_var = _zscored.var(axis=1)
    _zscored_var.name = 'Var'

    # Report the numbers of features failed to normalized
    _zscored_mean = _zscored_mean[~np.isclose(_zscored_mean.values, 0, atol=1E-01)]
    mdprint(f"## {rot}")
    display(_zscored_mean.to_frame().join(_zscored_var))
# Out:
# ## R05
#                                                                 Mean       Var
# ImagingFilter Category Name
# original      shape    Sphericity                           0.138331  0.982426
# lbp-3D-m1     glcm     Contrast                            -0.138789  0.871582
#                        Correlation                          0.244365  0.847523
#                        DifferenceAverage                   -0.118109  0.913178
#                        DifferenceVariance                  -0.152764  0.885028
# ...                                                              ...       ...
# wavelet-HHH   gldm     SmallDependenceEmphasis             -0.103954  0.972004
#                        SmallDependenceLowGrayLevelEmphasis -0.117836  0.886939
#               ngtdm    Complexity                           0.110444  1.002913
#                        Contrast                             0.110406  1.001659
# square        glrlm    ShortRunLowGrayLevelEmphasis        -0.221018  1.130622
#
# [311 rows x 2 columns]
# ## R10
#                                                               Mean       Var
# ImagingFilter Category   Name
# original      glszm      SizeZoneNonUniformityNormalized  0.248234  1.238423
#                          SmallAreaEmphasis                0.250340  1.324205
# lbp-3D-m1     firstorder Minimum                          0.113047  9.028754
#               glcm       Contrast                        -0.143049  0.867206
#                          Correlation                      0.253539  0.834224
# ...                                                            ...       ...
# square        glszm      SmallAreaLowGrayLevelEmphasis    0.101114  1.076459
# squareroot    glszm      SizeZoneNonUniformityNormalized  0.111457  1.004760
#                          SmallAreaEmphasis                0.124087  0.907123
# logarithm     glszm      SizeZoneNonUniformityNormalized  0.196317  1.046797
#                          SmallAreaEmphasis                0.246017  0.847203
#
# [397 rows x 2 columns]
# ## R15
#                                                             Mean       Var
# ImagingFilter Category Name
# original      glszm    SizeZoneNonUniformityNormalized  0.480832  1.461612
#                        SmallAreaEmphasis                0.480498  1.348799
#                        ZoneEntropy                     -0.102839  1.014792
# lbp-3D-m1     glcm     Contrast                        -0.147424  0.858020
#                        Correlation                      0.268719  0.832434
# ...                                                          ...       ...
# square        glszm    SmallAreaLowGrayLevelEmphasis    0.118485  0.904553
# squareroot    glszm    SizeZoneNonUniformityNormalized  0.145539  1.029799
#                        SmallAreaEmphasis                0.154088  0.963578
# logarithm     glszm    SizeZoneNonUniformityNormalized  0.304821  1.075881
#                        SmallAreaEmphasis                0.347879  0.843917
#
# [470 rows x 2 columns]
# ## R20
#                                                             Mean       Var
# ImagingFilter Category Name
# original      glszm    SizeZoneNonUniformity            0.133695  1.455065
#                        SizeZoneNonUniformityNormalized  0.570905  1.401857
#                        SmallAreaEmphasis                0.577467  1.351007
#                        SmallAreaHighGrayLevelEmphasis   0.105220  1.006400
#                        ZoneEntropy                     -0.109100  0.975651
# ...                                                          ...       ...
# squareroot    glszm    SizeZoneNonUniformityNormalized  0.273090  0.999240
#                        SmallAreaEmphasis                0.266323  0.918749
#                        SmallAreaLowGrayLevelEmphasis    0.107820  1.170568
# logarithm     glszm    SizeZoneNonUniformityNormalized  0.455325  1.106770
#                        SmallAreaEmphasis                0.477913  0.872249
#
# [518 rows x 2 columns]
# ## R25
#                                                             Mean       Var
# ImagingFilter Category Name
# original      glszm    SizeZoneNonUniformity            0.161251  1.411239
#                        SizeZoneNonUniformityNormalized  0.711305  1.521912
#                        SmallAreaEmphasis                0.714966  1.272452
#                        SmallAreaHighGrayLevelEmphasis   0.148192  1.018771
#                        SmallAreaLowGrayLevelEmphasis    0.113556  1.212287
# ...                                                          ...       ...
# logarithm     glszm    SizeZoneNonUniformityNormalized  0.570246  1.137837
#                        SmallAreaEmphasis                0.579286  0.894778
#                        SmallAreaHighGrayLevelEmphasis   0.131696  1.215930
#                        SmallAreaLowGrayLevelEmphasis    0.113487  1.278254
#                        ZoneEntropy                     -0.109149  1.003359
#
# [552 rows x 2 columns]
# ## R30
#                                                             Mean       Var
# ImagingFilter Category Name
# original      glszm    SizeZoneNonUniformity            0.156722  1.420258
#                        SizeZoneNonUniformityNormalized  0.790371  1.311072
#                        SmallAreaEmphasis                0.811405  1.150372
#                        SmallAreaHighGrayLevelEmphasis   0.138318  0.992310
#                        SmallAreaLowGrayLevelEmphasis    0.125093  1.221968
# ...                                                          ...       ...
# logarithm     glrlm    RunEntropy                       0.108784  1.124724
#               glszm    SizeZoneNonUniformityNormalized  0.595109  1.080855
#                        SmallAreaEmphasis                0.608124  0.868857
#                        SmallAreaHighGrayLevelEmphasis   0.147721  1.226457
#                        ZoneEntropy                     -0.107910  0.976616
#
# [577 rows x 2 columns]
# ## R35
#                                                             Mean       Var
# ImagingFilter Category Name
# original      glszm    SizeZoneNonUniformity            0.158253  1.368626
#                        SizeZoneNonUniformityNormalized  0.736556  1.406923
#                        SmallAreaEmphasis                0.731892  1.433582
#                        SmallAreaHighGrayLevelEmphasis   0.124010  0.959875
#                        SmallAreaLowGrayLevelEmphasis    0.117705  1.288333
# ...                                                          ...       ...
# squareroot    glszm    SmallAreaLowGrayLevelEmphasis    0.127929  1.274701
# logarithm     glszm    SizeZoneNonUniformityNormalized  0.602634  1.201598
#                        SmallAreaEmphasis                0.611406  0.973284
#                        SmallAreaHighGrayLevelEmphasis   0.119894  1.129383
#                        ZoneEntropy                     -0.111711  0.984920
#
# [603 rows x 2 columns]
# ## R40
#                                                             Mean       Var
# ImagingFilter Category Name
# original      glszm    SizeZoneNonUniformity            0.144354  1.377057
#                        SizeZoneNonUniformityNormalized  0.677905  1.467344
#                        SmallAreaEmphasis                0.694964  1.306453
#                        SmallAreaHighGrayLevelEmphasis   0.109126  0.958226
#                        SmallAreaLowGrayLevelEmphasis    0.124940  1.196756
# ...                                                          ...       ...
# squareroot    glszm    SizeZoneNonUniformityNormalized  0.330999  1.019325
#                        SmallAreaEmphasis                0.330723  0.925258
# logarithm     glszm    SizeZoneNonUniformityNormalized  0.569780  1.074128
#                        SmallAreaEmphasis                0.562989  1.089687
#                        SmallAreaHighGrayLevelEmphasis   0.127664  1.185937
#
# [618 rows x 2 columns]
# ## R45
#                                                             Mean       Var
# ImagingFilter Category Name
# original      glszm    SizeZoneNonUniformity            0.124807  1.249399
#                        SizeZoneNonUniformityNormalized  0.735998  1.486157
#                        SmallAreaEmphasis                0.759603  1.272390
#                        SmallAreaHighGrayLevelEmphasis   0.135706  0.979778
#                        SmallAreaLowGrayLevelEmphasis    0.124730  1.150371
# ...                                                          ...       ...
# squareroot    glszm    SizeZoneNonUniformityNormalized  0.375731  1.089293
#                        SmallAreaEmphasis                0.375819  0.931238
# logarithm     glszm    SizeZoneNonUniformityNormalized  0.562048  1.314333
#                        SmallAreaEmphasis                0.568027  0.981185
#                        SmallAreaHighGrayLevelEmphasis   0.119187  1.142319
#
# [614 rows x 2 columns]
# ## R50
#                                                             Mean       Var
# ImagingFilter Category Name
# original      shape    Maximum2DDiameterSlice           0.120069  1.240359
#               glszm    SizeZoneNonUniformity            0.127621  1.324493
#                        SizeZoneNonUniformityNormalized  0.695276  1.431698
#                        SmallAreaEmphasis                0.731690  1.128258
#                        SmallAreaHighGrayLevelEmphasis   0.114307  0.982606
# ...                                                          ...       ...
# squareroot    glszm    SmallAreaEmphasis                0.371544  0.809046
# logarithm     glszm    SizeZoneNonUniformityNormalized  0.541511  1.100374
#                        SmallAreaEmphasis                0.555471  0.873850
#                        SmallAreaHighGrayLevelEmphasis   0.127879  1.190874
#                        ZoneEntropy                     -0.101833  0.979672
#
# [621 rows x 2 columns]
# ## R55
#                                                             Mean       Var
# ImagingFilter Category Name
# original      shape    Maximum2DDiameterColumn         -0.105494  0.837348
#                        Maximum2DDiameterSlice           0.100430  1.165279
#               glszm    SizeZoneNonUniformity            0.135765  1.327921
#                        SizeZoneNonUniformityNormalized  0.747528  1.567715
#                        SmallAreaEmphasis                0.742626  1.363063
# ...                                                          ...       ...
# logarithm     glrlm    RunEntropy                       0.113713  1.069244
#               glszm    SizeZoneNonUniformityNormalized  0.608870  1.197802
#                        SmallAreaEmphasis                0.621244  0.845118
#                        SmallAreaHighGrayLevelEmphasis   0.160779  1.226113
#                        ZoneEntropy                     -0.103871  0.994964
#
# [630 rows x 2 columns]
# ## R60
#                                                             Mean       Var
# ImagingFilter Category Name
# original      shape    Maximum2DDiameterColumn         -0.108001  0.847065
#                        Maximum2DDiameterSlice           0.111652  1.244884
#               glszm    SizeZoneNonUniformity            0.154205  1.414326
#                        SizeZoneNonUniformityNormalized  0.730771  1.512981
#                        SmallAreaEmphasis                0.739829  1.339912
# ...                                                          ...       ...
# squareroot    glszm    SmallAreaLowGrayLevelEmphasis    0.111903  1.377803
# logarithm     glszm    SizeZoneNonUniformityNormalized  0.547126  1.080735
#                        SmallAreaEmphasis                0.558707  0.864436
#                        SmallAreaHighGrayLevelEmphasis   0.128430  1.227178
#                        ZoneEntropy                     -0.116402  1.008058
#
# [624 rows x 2 columns]
# ## R65
#                                                             Mean       Var
# ImagingFilter Category Name
# original      shape    Maximum2DDiameterColumn         -0.111174  0.810421
#                        Maximum2DDiameterSlice           0.132789  1.243881
#               glszm    SizeZoneNonUniformity            0.139793  1.352090
#                        SizeZoneNonUniformityNormalized  0.692958  1.524554
#                        SmallAreaEmphasis                0.695097  1.364734
# ...                                                          ...       ...
# squareroot    glszm    SmallAreaEmphasis                0.301986  0.907134
#                        SmallAreaLowGrayLevelEmphasis    0.106347  1.149559
# logarithm     glszm    SizeZoneNonUniformityNormalized  0.504875  1.024296
#                        SmallAreaEmphasis                0.541663  0.800382
#                        SmallAreaHighGrayLevelEmphasis   0.116165  1.142603
#
# [616 rows x 2 columns]
# ## R70
#                                                             Mean       Var
# ImagingFilter Category Name
# original      shape    Maximum2DDiameterColumn         -0.114994  0.828483
#                        Maximum2DDiameterSlice           0.148855  1.269793
#               glszm    SizeZoneNonUniformity            0.120958  1.211389
#                        SizeZoneNonUniformityNormalized  0.604010  1.457064
#                        SmallAreaEmphasis                0.626666  1.216167
# ...                                                          ...       ...
# squareroot    glszm    SmallAreaEmphasis                0.256275  0.970936
#                        SmallAreaLowGrayLevelEmphasis    0.140456  1.590537
# logarithm     glszm    SizeZoneNonUniformityNormalized  0.495136  1.192869
#                        SmallAreaEmphasis                0.494545  1.044675
#                        SmallAreaHighGrayLevelEmphasis   0.120357  1.250904
#
# [615 rows x 2 columns]
# ## R75
#                                                             Mean       Var
# ImagingFilter Category Name
# original      shape    Maximum2DDiameterColumn         -0.125052  0.795584
#                        Maximum2DDiameterSlice           0.160462  1.314497
#               glszm    SizeZoneNonUniformityNormalized  0.498632  1.446732
#                        SmallAreaEmphasis                0.517690  1.355889
# lbp-3D-m1     glcm     Contrast                        -0.143546  0.860111
# ...                                                          ...       ...
# square        glszm    SmallAreaLowGrayLevelEmphasis    0.228191  1.168555
# squareroot    glszm    SizeZoneNonUniformityNormalized  0.278025  1.008856
#                        SmallAreaEmphasis                0.274028  0.960056
# logarithm     glszm    SizeZoneNonUniformityNormalized  0.354936  1.039237
#                        SmallAreaEmphasis                0.386303  0.898399
#
# [616 rows x 2 columns]
# ## R80
#                                                             Mean       Var
# ImagingFilter Category Name
# original      shape    Maximum2DDiameterColumn         -0.122978  0.809664
#                        Maximum2DDiameterSlice           0.133891  1.254803
#               glszm    SizeZoneNonUniformityNormalized  0.343869  1.209709
#                        SmallAreaEmphasis                0.364188  1.187443
# lbp-3D-m1     glcm     Contrast                        -0.134769  0.877347
# ...                                                          ...       ...
# square        glszm    SmallAreaLowGrayLevelEmphasis    0.113818  1.035776
# squareroot    glszm    SizeZoneNonUniformityNormalized  0.197163  0.895272
#                        SmallAreaEmphasis                0.216189  0.781709
# logarithm     glszm    SizeZoneNonUniformityNormalized  0.278294  1.089923
#                        SmallAreaEmphasis                0.297002  1.029570
#
# [598 rows x 2 columns]

# %% [markdown]
# ## Steps for model training:
#
# Models were trained within the repeated K-fold iterations. In this study, we ran 5-fold cross-validation for 50 times individually using $X_{WD}$ and $X_{nWD}$ features. Therefore, there are a total of 500 runs (250 each for using exotically $X_{WD}$ or $X_{nWD}$). In each of the runs, we performed the following:
#
# 1. Grid search of various classifiers for optimal hyperparameters to discriminate between NSCLC subtypes.
# 2. Using the optimized criteria found in upper cell, train the model using K-fold training set and limit to using only $R_0$ features (from either $X_{WD}$ or $X_{nWD}$).
# 3. Test the trained model on the K-fold testing sets of $R_0$ to $R_{80}$ feature sets (from either $X_{WD}$ or $X_{nWD}$).
#
#
# ### Grid Search
#
# Using the function `GridSearchCV`, we tested different model hyperparameters of the chosen classifiers to determine the optimal set that will be used during K-fold cross-validation. The hyperparameters grid is defined as var `clf_card`.

# %%
'''Grid search for optimal training hyperparameters'''
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as imb_Pipeline

# Fine tunned to optimize accuracy
scoring_func_name = "roc_auc_ovr_weighted"
scoring_func = metrics.accuracy_score
global_config = {
    'ANOVA_pthres': 0.05, 
    'var_thres': 1E-4,
    'alpha': 0.01, 
    'l1_ratio': 0.9, 
    'n_features': 50, 
    'N': 50,
    'K': 5
}
switch = {
    'AddGridSearch': True,  # Perform grid search grid-search in loop rather than doing it now and use same hyperparams
    'AddSMOTE': False,      # Add SMOTE during K-fold training. Otherwise, its only on during feature selection
    'UpdateStandardization': True # Update the normalization parameter using rotated training data
}

verbose=False
clf_card = {
    'Support Vector Machine': {
        # Takes too many iterations for SVM to converge with tol < 1E-3. RBF kernel notably takes
        # upto 100,000 iterations to converge with tol = 1E-3, which is only 0.1% of the score function
        'classification': [sklearn.svm.SVC(tol=1E-4, max_iter=-1, probability=True,  decision_function_shape='ovr',verbose=verbose, 
                                           )],
        'classification__kernel': ['linear'],
        'classification__C': [0.1, 1, 10, 100],
    },
    'Support Vector Machine (rbf)': {
        # Takes too many iterations for SVM to converge with tol < 1E-3. RBF kernel notably takes
        # upto 100,000 iterations to converge with tol = 1E-3
        'classification': [sklearn.svm.SVC(tol=1E-4, max_iter=-1, probability=True,  decision_function_shape='ovr', verbose=verbose, 
                                           )],
        'classification__kernel': ['rbf'],
        'classification__C': [0.1, 1, 10, 100],
        'classification__shrinking': [False, True], 
        'classification__gamma': ['auto', 'scale']
    },
    'Logistic Regression': {
        'classification': [sklearn.linear_model.LogisticRegression(penalty='elasticnet',
                                                           solver='saga', tol=1E-4,
                                                           max_iter=10000,
                                                           verbose=verbose)],
        'classification__C': [0.1, 1, 100, 1000],
        'classification__l1_ratio': [0.1, 0.9]
    },
    'Random Forest': {
        'classification': [sklearn.ensemble.RandomForestClassifier(verbose=verbose)],
        'classification__n_estimators': [20, 30, 50, 100],
        'classification__criterion': ['gini', 'entropy'],
        'classification__max_depth': [None, 5, 10, 20]
    }, 
    'KNN': {
        'classification': [sklearn.neighbors.KNeighborsClassifier()], 
        'classification__n_neighbors': [3, 5, 7, 10]
    }, 
}

def normalize_n_feature_selection(X: pd.DataFrame,
                                  y: Union[pd.Series, pd.DataFrame],
                                  X_hold_out: pd.DataFrame,
                                  **kwargs) -> Tuple[pd.DataFrame, pd.DataFrame, pd.Index]:
    """Performs normalization and supervised feature selection on given data.

    This function first applies normalization to the data. It then uses Synthetic Minority 
    Over-sampling Technique (SMOTE) to balance the classes before performing supervised 
    feature selection. Feature selection is performed using Elastic Net and only features 
    with non-zero coefficients are selected.

    Args:
        X (pd.DataFrame): 
            The input features to be normalized and for feature selection. Each row is a feature
            and each column is a sample.
        y (Union[pd.Series, pd.DataFrame]): 
            The target variable corresponding to the input features.
        X_hold_out (pd.DataFrame): 
            The hold-out set of input features to be transformed based on the transformations 
            applied on X.
        **kwargs: 
            Additional parameters to be passed to the normalization and feature selection functions.

    Returns:
        Tuple[pd.DataFrame, pd.DataFrame, pd.Index]:
            X (pd.DataFrame): 
                The normalized and feature-selected dataframe of input features. 
            X_hold_out (pd.DataFrame): 
                The transformed and feature-selected dataframe of hold-out input features.
            sup_selected_feats.index (pd.Index): 
                The index of features selected during supervised feature selection.
            
    .. notes::
        The number of selected features is limited to 25 to keep it to a reasonable number. 
        The output DataFrames `X` and `X_hold_out` will have their index sorted as a side effect of the feature selection process.
        The output are normalized using `normalizer_cls()`. If you don't want normalized output
        please use `sup_selected_feats.index` output to select the features from the raw input `X`.
    """
    # Perform normalization
    normalizer = normalizer_cls()
    X_normed = normalizer.fit_transform(X.T).T
    X = pd.DataFrame(data=X_normed, index=X.index, columns=X.columns)
    X_hold_out_normed = normalizer.transform(X_hold_out.T).T
    X_hold_out = pd.DataFrame(data=X_hold_out_normed, index=X_hold_out.index, columns=X_hold_out.columns)
    
    # Smote to balance class before supervised feature selection
    smote_sampler = SMOTE()
    X_smote, y_smote = smote_sampler.fit_resample(X.T, y) # X.T: (n_samples, n_features)
    X_smote = X_smote.T # X_smote: (n_features, n_samples)
    y_smote = pd.DataFrame(y_smote, index=X_smote.columns)
    y = y_smote
    
    # Before K-fold, perform fine feature selection using all training data, features are selected
    # if its ENet coefficients are non-zero. Note: Set `n_trials`=1 to use one ElasticNet
    sup_selected_feats = supervised_features_selection(
        X_smote,
        y.to_frame() if isinstance(y, pd.Series) else y,
        alpha=global_config['alpha'],
        l1_ratio=global_config['l1_ratio'], 
        n_trials=1,
        boosting=False,
        n_features=global_config['n_features'],    # Keep the number of selected features limited to a reasonable number
    )
    X = X.loc[sup_selected_feats.index] # Note that output has its index sorted
    if not X_hold_out is None:
        X_hold_out = X_hold_out.loc[X.index] # Also apply results to X_hold_out
    return X, X_hold_out, sup_selected_feats.index


def get_best_hyperparameters(X: pd.DataFrame, 
                             gt: Union[pd.DataFrame, pd.Series]) -> Tuple[dict, dict, pd.Index]:
    r"""
    Get best hyperparameters for a given dataset and ground truth labels using cross-validated grid search.
    
    The function first standardizes the input data using RobustScaler, then applies preliminary feature
    filtering. After that, it performs cross-validated grid search to find the best hyperparameters for the
    model, and return the instance of the model created using these best hyperparameters.

    Arg:
        X (pd.DataFrame):
            The input data, where each row is a sample and each column is a feature.
        gt (Union[pd.DataFrame, pd.Series]):
            The ground truth labels for each sample.

    Returns:
        Tuple[dict, dict, pd.Index]
            A tuple containing three elements:
                - best_params: A dictionary of the best hyperparameters found by the grid search.
                - best_estimators: A dictionary of the best models for each class, with classes as keys.
                - X_train.index: The index of the samples in the training set after feature filtering.

    Raises:
        ValueError
            If the input parameters are not in the expected format or if the grid search does not converge.
    """
    # Zscore normalization
    zscored = normalizer_cls().fit_transform(X.T).T
    X = pd.DataFrame(data=zscored, index=X.index, columns=X.columns)

    # Use custom pipeline that changes the standardization
    clf = sklearn.pipeline.Pipeline([
        ('standardization', normalizer_cls()),
        ('classification', 'passthrough')
    ]) 

    gt = gt.to_frame() if isinstance(gt, pd.Series) else gt

    # Feature selection
    X_train, _ = preliminary_feature_filtering(X, None, gt, 
                                               p_thres=global_config['ANOVA_pthres'], var_thres = global_config['var_thres'])
    
    # Fine feature selection
    __, __, chosen_feats = normalize_n_feature_selection(
        X_train,
        gt,
        X_train # Place-holder, have no use.
    )
    X_train = X_train.loc[chosen_feats]

    
    # Perform CV grid search for best hyperparams
    best_params, results, predict_table, best_estimators = cv_grid_search(
        X_train.T, gt.astype('int'),
        param_grid_dict=clf_card,
        scoring=scoring_func_name,
        clf=clf, 
        refit=True, 
        n_jobs=10
    )
    return best_params, best_estimators, X_train.index

X_R0 = {
    'WD' : X_WD_R0,
    'nWD': X_nWD_R0
}

mdprint("## Hyperparameters grid search")
try:
    if not switch['AddGridSearch']:
        with open(resource_root / 'pipelines_v2.joblib', 'rb') as f:
            best_estimators = joblib.load(f)

        with open(resource_root / 'bestparams_v2.joblib', 'rb') as f:
            best_params = joblib.load(f)

        with open(resource_root / 'prelim_features_v2.joblib', 'rb') as f:
            prelim_features = joblib.load(f)
        mdprint("Successfully loaded checkpoints.")
    else:
        mdprint("Not loading best estimators because GridSearch is done within loop")
except Exception as e:
    # It takes a lot of time to do grid search so this is established
    mdprint("Checkpoints not found, re-do initial hyperparameter grid search")
    best_params = {}
    best_estimators = {}
    prelim_features = {}
    for name, _X in X_R0.items():
        # ! Add SMOTE if its on
        if switch['AddSMOTE']:
            smote_sampler = SMOTE()
            _X, _y = smote_sampler.fit_resample(_X.T, y) # X.T: (n_samples, n_features)
            _X = _X.T # X_smote: (n_features, n_samples)
            _y = pd.DataFrame(_y, index=_X.columns)
        else:
            _y = y.copy()
        
        # Perform preliminary feature filtering
        best_params[name], best_estimators[name], prelim_features[name] = get_best_hyperparameters(_X, _y)

    # check if the best_estimators has converged properly
    for feat_gp in best_estimators:
        for model_name, model in best_estimators[feat_gp].items():
            try:
                if model[1].fit_status_:
                    msg = f"{(feat_gp, model_name)} did not converge for the best_estimator."
                    print(msg)
            except AttributeError:
                continue
            except Exception as e:
                raise e

    # Save the selected features
    with open(resource_root / 'pipelines_v2.joblib', 'wb') as f:
        joblib.dump(best_estimators, f)

    with open(resource_root / 'bestparams_v2.joblib', 'wb') as f:
        joblib.dump(best_params, f)

    with open(resource_root / 'prelim_features_v2.joblib', 'wb') as f:
        joblib.dump(prelim_features, f)
# Out:
# ## Hyperparameters grid search
# Checkpoints not found, re-do initial hyperparameter grid search
# [2024-02-24 04:38:19,366-INFO] (preliminary_feature_filtering) Dropping 'Diganostics' column.
# [2024-02-24 04:38:19,367-ERROR] (preliminary_feature_filtering) Diagnostics column generated by PyRadiomics is not found or error occurs.
# [2024-02-24 04:38:19,367-INFO] (preliminary_feature_filtering) Dropping 'Diganostics' column.
# [2024-02-24 04:38:19,367-INFO] (preliminary_feature_filtering) Dropping features with low variance with threshold 0.0001...
# [2024-02-24 04:38:19,376-INFO] (preliminary_feature_filtering) Dropped 0 features for first feature set.
# [2024-02-24 04:38:19,376-INFO] (preliminary_feature_filtering) Second feature set not found. ICC filtering skipped.
# [2024-02-24 04:38:19,377-INFO] (preliminary_feature_filtering) Dropping features using T-test or ANOVA with p-value threshold: 0.05
# [2024-02-24 04:38:19,378-INFO] (preliminary_feature_filtering) Using ANOVA
# [2024-02-24 04:38:19,522-DEBUG] (ANOVA) Normality Shapiro results:
#                                                                Statistics          pval
# ImagingFilter Category   Name
# wavelet-HHH   firstorder 10Percentile                            0.950090  7.727644e-09
#                          90Percentile                            0.948235  4.670826e-09
#                          Energy                                  0.515497  1.840070e-28
#                          Entropy                                 0.245893  1.040933e-33
#                          InterquartileRange                      0.946670  3.079808e-09
#                          Kurtosis                                0.328340  2.727832e-32
#                          Maximum                                 0.748113  1.474408e-21
#                          MeanAbsoluteDeviation                   0.950062  7.668041e-09
#                          Mean                                    0.541025  7.495039e-28
#                          Median                                  0.595088  1.820616e-26
#                          Minimum                                 0.792927  1.091594e-19
#                          Range                                   0.772025  1.354624e-20
#                          RobustMeanAbsoluteDeviation             0.947330  3.668265e-09
#                          RootMeanSquared                         0.952021  1.321322e-08
#                          Skewness                                0.458765  9.891530e-30
#                          TotalEnergy                             0.515497  1.840070e-28
#                          Uniformity                              0.245951  1.043210e-33
#                          Variance                                0.821787  2.562058e-18
#               glcm       Autocorrelation                         0.931930  8.490406e-11
#                          ClusterProminence                       0.958052  7.704966e-08
#                          ClusterShade                            0.787596  6.318707e-20
#                          ClusterTendency                         0.958144  7.924853e-08
#                          Contrast                                0.958008  7.602795e-08
#                          Correlation                             0.958070  7.748286e-08
#                          DifferenceAverage                       0.958008  7.602795e-08
#                          DifferenceEntropy                       0.897904  1.067257e-13
#                          DifferenceVariance                      0.897903  1.067158e-13
#                          Id                                      0.958009  7.605531e-08
#                          Idm                                     0.958009  7.605531e-08
#                          Idmn                                    0.958009  7.605531e-08
#                          Idn                                     0.958009  7.605531e-08
#                          Imc1                                    0.897931  1.072333e-13
#                          Imc2                                    0.965904  9.678494e-07
#                          InverseVariance                         0.958008  7.602795e-08
#                          JointAverage                            0.808647  5.829793e-19
#                          JointEnergy                             0.899122  1.317398e-13
#                          JointEntropy                            0.898985  1.286399e-13
#                          MCC                                     0.965390  8.124534e-07
#                          MaximumProbability                      0.974765  2.538467e-05
#                          SumAverage                              0.808647  5.829793e-19
#                          SumEntropy                              0.980470  2.811517e-04
#                          SumSquares                              0.333079  3.323039e-32
#               glrlm      GrayLevelNonUniformity                  0.762400  5.436896e-21
#                          GrayLevelNonUniformityNormalized        0.132892  1.837813e-35
#                          GrayLevelVariance                       0.132892  1.837813e-35
#                          HighGrayLevelRunEmphasis                0.575246  5.442188e-27
#                          LongRunEmphasis                         0.930538  6.211868e-11
#                          LongRunHighGrayLevelEmphasis            0.929079  4.497153e-11
#                          LongRunLowGrayLevelEmphasis             0.929974  5.480260e-11
#                          LowGrayLevelRunEmphasis                 0.575245  5.442076e-27
#                          RunEntropy                              0.893590  5.132874e-14
#                          RunLengthNonUniformity                  0.766593  8.064327e-21
#                          RunLengthNonUniformityNormalized        0.875054  2.743493e-15
#                          RunPercentage                           0.939202  4.659712e-10
#                          RunVariance                             0.939526  5.042159e-10
#                          ShortRunEmphasis                        0.947989  4.372610e-09
#                          ShortRunHighGrayLevelEmphasis           0.943583  1.384469e-09
#                          ShortRunLowGrayLevelEmphasis            0.939207  4.665502e-10
#               glszm      GrayLevelNonUniformity                  0.699784  2.607194e-23
#                          GrayLevelNonUniformityNormalized        0.722444  1.617243e-22
#                          GrayLevelVariance                       0.722448  1.617787e-22
#                          HighGrayLevelZoneEmphasis               0.914403  2.173415e-12
#                          LargeAreaEmphasis                       0.491191  5.095835e-29
#                          LargeAreaHighGrayLevelEmphasis          0.491253  5.112309e-29
#                          LargeAreaLowGrayLevelEmphasis           0.491135  5.081042e-29
#                          LowGrayLevelZoneEmphasis                0.914403  2.173181e-12
#                          SizeZoneNonUniformity                   0.464823  1.335541e-29
#                          SizeZoneNonUniformityNormalized         0.823718  3.206342e-18
#                          SmallAreaEmphasis                       0.846911  5.517284e-17
#                          SmallAreaHighGrayLevelEmphasis          0.823714  3.204659e-18
#                          SmallAreaLowGrayLevelEmphasis           0.827267  4.864598e-18
#                          ZoneEntropy                             0.849196  7.424187e-17
#                          ZonePercentage                          0.447507  5.701954e-30
#                          ZoneVariance                            0.423983  1.854966e-30
#               gldm       DependenceEntropy                       0.973205  1.375670e-05
#                          DependenceNonUniformity                 0.733064  3.956948e-22
#                          DependenceNonUniformityNormalized       0.973185  1.364667e-05
#                          DependenceVariance                      0.930115  5.653597e-11
#                          GrayLevelNonUniformity                  0.757001  3.297797e-21
#                          GrayLevelVariance                       0.245951  1.043210e-33
#                          HighGrayLevelEmphasis                   0.747692  1.419997e-21
#                          LargeDependenceEmphasis                 0.969839  3.883073e-06
#                          LargeDependenceHighGrayLevelEmphasis    0.968657  2.533475e-06
#                          LargeDependenceLowGrayLevelEmphasis     0.964811  6.682989e-07
#                          LowGrayLevelEmphasis                    0.747692  1.419945e-21
#                          SmallDependenceEmphasis                 0.801673  2.738826e-19
#                          SmallDependenceHighGrayLevelEmphasis    0.801311  2.635060e-19
#                          SmallDependenceLowGrayLevelEmphasis     0.798401  1.934757e-19
#               ngtdm      Busyness                                0.756362  3.110231e-21
#                          Coarseness                              0.396237  5.165453e-31
#                          Complexity                              0.957418  6.357911e-08
#                          Contrast                                0.957076  5.735995e-08
#                          Strength                                0.396105  5.134726e-31
# wavelet-HHL   firstorder 10Percentile                            0.955065  3.161762e-08
#                          90Percentile                            0.957626  6.771148e-08
#                          Energy                                  0.540228  7.167033e-28
#                          Entropy                                 0.489689  4.714813e-29
#                          InterquartileRange                      0.947758  4.110564e-09
#                          Kurtosis                                0.291116  6.011988e-33
#                          Maximum                                 0.742205  8.736495e-22
#                          MeanAbsoluteDeviation                   0.957584  6.684959e-08
#                          Mean                                    0.660624  1.407850e-24
#                          Median                                  0.746273  1.251383e-21
#                          Minimum                                 0.667813  2.357751e-24
#                          Range                                   0.716860  1.020921e-22
#                          RobustMeanAbsoluteDeviation             0.950309  8.206304e-09
#                          RootMeanSquared                         0.963750  4.692459e-07
#                          Skewness                                0.604063  3.192069e-26
#                          TotalEnergy                             0.540228  7.167033e-28
#                          Uniformity                              0.554863  1.646854e-27
#                          Variance                                0.857001  2.099230e-16
#               glcm       Autocorrelation                         0.364905  1.288602e-31
#                          ClusterProminence                       0.276420  3.367674e-33
#                          ClusterShade                            0.737195  5.645325e-22
#                          ClusterTendency                         0.956893  5.430368e-08
#                          Contrast                                0.966070  1.024493e-06
#                          Correlation                             0.952081  1.343683e-08
#                          DifferenceAverage                       0.953204  1.846965e-08
#                          DifferenceEntropy                       0.910009  9.395127e-13
#                          DifferenceVariance                      0.837074  1.592167e-17
#                          Id                                      0.951636  1.185906e-08
#                          Idm                                     0.951937  1.290302e-08
#                          Idmn                                    0.787181  6.058330e-20
#                          Idn                                     0.860285  3.290695e-16
#                          Imc1                                    0.910614  1.052735e-12
#                          Imc2                                    0.966585  1.222999e-06
#                          InverseVariance                         0.951294  1.077947e-08
#                          JointAverage                            0.573078  4.782278e-27
#                          JointEnergy                             0.905584  4.149962e-13
#                          JointEntropy                            0.742554  9.008521e-22
#                          MCC                                     0.852822  1.197331e-16
#                          MaximumProbability                      0.955439  3.527957e-08
#                          SumAverage                              0.573078  4.782278e-27
#                          SumEntropy                              0.990552  4.084055e-02
#                          SumSquares                              0.401870  6.670449e-31
#               glrlm      GrayLevelNonUniformity                  0.762187  5.329679e-21
#                          GrayLevelNonUniformityNormalized        0.459039  1.002661e-29
#                          GrayLevelVariance                       0.361640  1.118568e-31
#                          HighGrayLevelRunEmphasis                0.364086  1.243610e-31
#                          LongRunEmphasis                         0.957198  5.950042e-08
#                          LongRunHighGrayLevelEmphasis            0.478964  2.720570e-29
#                          LongRunLowGrayLevelEmphasis             0.866100  7.434609e-16
#                          LowGrayLevelRunEmphasis                 0.633499  2.164316e-25
#                          RunEntropy                              0.881752  7.613865e-15
#                          RunLengthNonUniformity                  0.763904  6.259024e-21
#                          RunLengthNonUniformityNormalized        0.896022  7.734393e-14
#                          RunPercentage                           0.967036  1.429999e-06
#                          RunVariance                             0.946192  2.716665e-09
#                          ShortRunEmphasis                        0.977042  6.416626e-05
#                          ShortRunHighGrayLevelEmphasis           0.373286  1.857990e-31
#                          ShortRunLowGrayLevelEmphasis            0.713730  7.912799e-23
#               glszm      GrayLevelNonUniformity                  0.397352  5.432876e-31
#                          GrayLevelNonUniformityNormalized        0.969267  3.154242e-06
#                          GrayLevelVariance                       0.684588  8.127865e-24
#                          HighGrayLevelZoneEmphasis               0.535530  5.511366e-28
#                          LargeAreaEmphasis                       0.358530  9.780251e-32
#                          LargeAreaHighGrayLevelEmphasis          0.461928  1.156671e-29
#                          LargeAreaLowGrayLevelEmphasis           0.291279  6.050857e-33
#                          LowGrayLevelZoneEmphasis                0.981445  4.363613e-04
#                          SizeZoneNonUniformity                   0.522171  2.641147e-28
#                          SizeZoneNonUniformityNormalized         0.939204  4.662083e-10
#                          SmallAreaEmphasis                       0.950309  8.206213e-09
#                          SmallAreaHighGrayLevelEmphasis          0.641426  3.698348e-25
#                          SmallAreaLowGrayLevelEmphasis           0.948903  5.591498e-09
#                          ZoneEntropy                             0.971707  7.761147e-06
#                          ZonePercentage                          0.502554  9.230279e-29
#                          ZoneVariance                            0.373916  1.910046e-31
#               gldm       DependenceEntropy                       0.980777  3.225467e-04
#                          DependenceNonUniformity                 0.733546  4.123634e-22
#                          DependenceNonUniformityNormalized       0.980956  3.495688e-04
#                          DependenceVariance                      0.929627  5.073999e-11
#                          GrayLevelNonUniformity                  0.756859  3.255120e-21
#                          GrayLevelVariance                       0.396409  5.205861e-31
#                          HighGrayLevelEmphasis                   0.365417  1.317595e-31
#                          LargeDependenceEmphasis                 0.984125  1.529773e-03
#                          LargeDependenceHighGrayLevelEmphasis    0.411601  1.042269e-30
#                          LargeDependenceLowGrayLevelEmphasis     0.772374  1.400955e-20
#                          LowGrayLevelEmphasis                    0.640934  3.576510e-25
#                          SmallDependenceEmphasis                 0.823408  3.092325e-18
#                          SmallDependenceHighGrayLevelEmphasis    0.381151  2.628665e-31
#                          SmallDependenceLowGrayLevelEmphasis     0.891442  3.592034e-14
#               ngtdm      Busyness                                0.514874  1.779340e-28
#                          Coarseness                              0.396947  5.333992e-31
#                          Complexity                              0.458794  9.906211e-30
#                          Contrast                                0.750993  1.909314e-21
#                          Strength                                0.397910  5.571851e-31
# wavelet-HLH   firstorder 10Percentile                            0.944179  1.612108e-09
#                          90Percentile                            0.949978  7.492961e-09
#                          Energy                                  0.665954  2.061819e-24
#                          Entropy                                 0.230056  5.746619e-34
#                          InterquartileRange                      0.920782  7.745523e-12
#                          Kurtosis                                0.322101  2.107374e-32
#                          Maximum                                 0.682696  7.051244e-24
#                          MeanAbsoluteDeviation                   0.952107  1.353666e-08
#                          Mean                                    0.545131  9.448668e-28
#                          Median                                  0.457998  9.524533e-30
#                          Minimum                                 0.753799  2.461406e-21
#                          Range                                   0.712628  7.237755e-23
#                          RobustMeanAbsoluteDeviation             0.927639  3.283145e-11
#                          RootMeanSquared                         0.966057  1.019696e-06
#                          Skewness                                0.771499  1.287758e-20
#                          TotalEnergy                             0.665954  2.061839e-24
#                          Uniformity                              0.202159  2.066350e-34
#                          Variance                                0.835297  1.279526e-17
#               glcm       Autocorrelation                         0.120346  1.205852e-35
#                          ClusterProminence                       0.993064  1.553669e-01
#                          ClusterShade                            0.674372  3.802842e-24
#                          ClusterTendency                         0.992354  1.069316e-01
#                          Contrast                                0.993147  1.621858e-01
#                          Correlation                             0.992838  1.380264e-01
#                          DifferenceAverage                       0.993126  1.604655e-01
#                          DifferenceEntropy                       0.875671  3.009130e-15
#                          DifferenceVariance                      0.876316  3.315228e-15
#                          Id                                      0.993121  1.599806e-01
#                          Idm                                     0.993123  1.601766e-01
#                          Idmn                                    0.767610  8.880030e-21
#                          Idn                                     0.951592  1.171515e-08
#                          Imc1                                    0.878861  4.877246e-15
#                          Imc2                                    0.929797  5.268507e-11
#                          InverseVariance                         0.993114  1.594251e-01
#                          JointAverage                            0.118170  1.121417e-35
#                          JointEnergy                             0.838149  1.818869e-17
#                          JointEntropy                            0.850653  8.987425e-17
#                          MCC                                     0.923314  1.306975e-11
#                          MaximumProbability                      0.798725  2.002080e-19
#                          SumAverage                              0.118170  1.121417e-35
#                          SumEntropy                              0.952286  1.423799e-08
#                          SumSquares                              0.261073  1.857180e-33
#               glrlm      GrayLevelNonUniformity                  0.755535  2.883332e-21
#                          GrayLevelNonUniformityNormalized        0.137161  2.123536e-35
#                          GrayLevelVariance                       0.159144  4.511086e-35
#                          HighGrayLevelRunEmphasis                0.092203  4.768419e-36
#                          LongRunEmphasis                         0.994676  3.476312e-01
#                          LongRunHighGrayLevelEmphasis            0.585868  1.032959e-26
#                          LongRunLowGrayLevelEmphasis             0.906752  5.135195e-13
#                          LowGrayLevelRunEmphasis                 0.122542  1.297682e-35
#                          RunEntropy                              0.987662  8.923890e-03
#                          RunLengthNonUniformity                  0.749004  1.596709e-21
#                          RunLengthNonUniformityNormalized        0.991700  7.548160e-02
#                          RunPercentage                           0.990449  3.865428e-02
#                          RunVariance                             0.991119  5.532539e-02
#                          ShortRunEmphasis                        0.994115  2.652414e-01
#                          ShortRunHighGrayLevelEmphasis           0.298910  8.207180e-33
#                          ShortRunLowGrayLevelEmphasis            0.611215  5.029111e-26
#               glszm      GrayLevelNonUniformity                  0.862080  4.221215e-16
#                          GrayLevelNonUniformityNormalized        0.847665  6.083135e-17
#                          GrayLevelVariance                       0.542150  7.984639e-28
#                          HighGrayLevelZoneEmphasis               0.788870  7.193872e-20
#                          LargeAreaEmphasis                       0.468053  1.569176e-29
#                          LargeAreaHighGrayLevelEmphasis          0.471247  1.841723e-29
#                          LargeAreaLowGrayLevelEmphasis           0.467551  1.530274e-29
#                          LowGrayLevelZoneEmphasis                0.983273  1.018579e-03
#                          SizeZoneNonUniformity                   0.795165  1.377499e-19
#                          SizeZoneNonUniformityNormalized         0.976576  5.291486e-05
#                          SmallAreaEmphasis                       0.892604  4.354662e-14
#                          SmallAreaHighGrayLevelEmphasis          0.969757  3.768556e-06
#                          SmallAreaLowGrayLevelEmphasis           0.962061  2.703773e-07
#                          ZoneEntropy                             0.965013  7.151120e-07
#                          ZonePercentage                          0.464879  1.339326e-29
#                          ZoneVariance                            0.455768  8.534989e-30
#               gldm       DependenceEntropy                       0.995067  4.160807e-01
#                          DependenceNonUniformity                 0.722279  1.595308e-22
#                          DependenceNonUniformityNormalized       0.994947  3.940824e-01
#                          DependenceVariance                      0.961385  2.176435e-07
#                          GrayLevelNonUniformity                  0.756994  3.295740e-21
#                          GrayLevelVariance                       0.213638  3.136549e-34
#                          HighGrayLevelEmphasis                   0.105678  7.413280e-36
#                          LargeDependenceEmphasis                 0.995086  4.194693e-01
#                          LargeDependenceHighGrayLevelEmphasis    0.490423  4.897121e-29
#                          LargeDependenceLowGrayLevelEmphasis     0.811661  8.131927e-19
#                          LowGrayLevelEmphasis                    0.156999  4.188523e-35
#                          SmallDependenceEmphasis                 0.814731  1.145923e-18
#                          SmallDependenceHighGrayLevelEmphasis    0.633071  2.103119e-25
#                          SmallDependenceLowGrayLevelEmphasis     0.825393  3.900557e-18
#               ngtdm      Busyness                                0.744052  1.027942e-21
#                          Coarseness                              0.385811  3.233907e-31
#                          Complexity                              0.156396  4.102093e-35
#                          Contrast                                0.691005  1.322500e-23
#                          Strength                                0.386595  3.349041e-31
# wavelet-HLL   firstorder 10Percentile                            0.926480  2.556155e-11
#                          90Percentile                            0.919511  5.980846e-12
#                          Energy                                  0.700477  2.752585e-23
#                          Entropy                                 0.881230  7.022204e-15
#                          InterquartileRange                      0.875863  3.097121e-15
#                          Kurtosis                                0.223776  4.553006e-34
#                          Maximum                                 0.872645  1.918663e-15
#                          MeanAbsoluteDeviation                   0.936182  2.263414e-10
#                          Mean                                    0.720031  1.324629e-22
#                          Median                                  0.595446  1.861523e-26
#                          Minimum                                 0.736187  5.174499e-22
#                          Range                                   0.801920  2.812232e-19
#                          RobustMeanAbsoluteDeviation             0.892866  4.548671e-14
#                          RootMeanSquared                         0.953168  1.828454e-08
#                          Skewness                                0.663883  1.776737e-24
#                          TotalEnergy                             0.700477  2.752585e-23
#                          Uniformity                              0.856385  1.931256e-16
#                          Variance                                0.802229  2.906714e-19
#               glcm       Autocorrelation                         0.483879  3.496256e-29
#                          ClusterProminence                       0.406965  8.420290e-31
#                          ClusterShade                            0.588955  1.247415e-26
#                          ClusterTendency                         0.697495  2.181108e-23
#                          Contrast                                0.770586  1.179587e-20
#                          Correlation                             0.996677  7.633079e-01
#                          DifferenceAverage                       0.942597  1.078790e-09
#                          DifferenceEntropy                       0.847187  5.718082e-17
#                          DifferenceVariance                      0.682658  7.031564e-24
#                          Id                                      0.992912  1.435039e-01
#                          Idm                                     0.985130  2.493980e-03
#                          Idmn                                    0.824215  3.397675e-18
#                          Idn                                     0.957177  5.912830e-08
#                          Imc1                                    0.971240  6.514351e-06
#                          Imc2                                    0.983914  1.382354e-03
#                          InverseVariance                         0.988446  1.340603e-02
#                          JointAverage                            0.730873  3.282906e-22
#                          JointEnergy                             0.908430  6.997071e-13
#                          JointEntropy                            0.866001  7.329960e-16
#                          MCC                                     0.971190  6.392585e-06
#                          MaximumProbability                      0.872183  1.792416e-15
#                          SumAverage                              0.730873  3.282906e-22
#                          SumEntropy                              0.889149  2.467272e-14
#                          SumSquares                              0.679701  5.638466e-24
#               glrlm      GrayLevelNonUniformity                  0.745601  1.178884e-21
#                          GrayLevelNonUniformityNormalized        0.892849  4.535597e-14
#                          GrayLevelVariance                       0.780893  3.223908e-20
#                          HighGrayLevelRunEmphasis                0.482379  3.237943e-29
#                          LongRunEmphasis                         0.988522  1.394520e-02
#                          LongRunHighGrayLevelEmphasis            0.507909  1.225765e-28
#                          LongRunLowGrayLevelEmphasis             0.833742  1.058161e-17
#                          LowGrayLevelRunEmphasis                 0.746996  1.334566e-21
#                          RunEntropy                              0.996254  6.683929e-01
#                          RunLengthNonUniformity                  0.758557  3.805546e-21
#                          RunLengthNonUniformityNormalized        0.968055  2.045309e-06
#                          RunPercentage                           0.977932  9.325278e-05
#                          RunVariance                             0.982019  5.675483e-04
#                          ShortRunEmphasis                        0.980543  2.904798e-04
#                          ShortRunHighGrayLevelEmphasis           0.489419  4.649366e-29
#                          ShortRunLowGrayLevelEmphasis            0.769354  1.048443e-20
#               glszm      GrayLevelNonUniformity                  0.778345  2.506343e-20
#                          GrayLevelNonUniformityNormalized        0.985749  3.385586e-03
#                          GrayLevelVariance                       0.649861  6.607721e-25
#                          HighGrayLevelZoneEmphasis               0.520778  2.448397e-28
#                          LargeAreaEmphasis                       0.304226  1.016470e-32
#                          LargeAreaHighGrayLevelEmphasis          0.186724  1.187930e-34
#                          LargeAreaLowGrayLevelEmphasis           0.234445  6.768336e-34
#                          LowGrayLevelZoneEmphasis                0.828886  5.896053e-18
#                          SizeZoneNonUniformity                   0.748968  1.591578e-21
#                          SizeZoneNonUniformityNormalized         0.827038  4.734702e-18
#                          SmallAreaEmphasis                       0.963023  3.694040e-07
#                          SmallAreaHighGrayLevelEmphasis          0.424923  1.938667e-30
#                          SmallAreaLowGrayLevelEmphasis           0.820088  2.106256e-18
#                          ZoneEntropy                             0.956191  4.405438e-08
#                          ZonePercentage                          0.787618  6.333093e-20
#                          ZoneVariance                            0.304965  1.047279e-32
#               gldm       DependenceEntropy                       0.981285  4.057403e-04
#                          DependenceNonUniformity                 0.712450  7.134075e-23
#                          DependenceNonUniformityNormalized       0.984581  1.907269e-03
#                          DependenceVariance                      0.961973  2.627991e-07
#                          GrayLevelNonUniformity                  0.747732  1.425009e-21
#                          GrayLevelVariance                       0.709477  5.616053e-23
#                          HighGrayLevelEmphasis                   0.484330  3.577955e-29
#                          LargeDependenceEmphasis                 0.995010  4.054969e-01
#                          LargeDependenceHighGrayLevelEmphasis    0.511171  1.458796e-28
#                          LargeDependenceLowGrayLevelEmphasis     0.730122  3.080109e-22
#                          LowGrayLevelEmphasis                    0.723529  1.769988e-22
#                          SmallDependenceEmphasis                 0.839130  2.055063e-17
#                          SmallDependenceHighGrayLevelEmphasis    0.518150  2.123365e-28
#                          SmallDependenceLowGrayLevelEmphasis     0.738491  6.316395e-22
#               ngtdm      Busyness                                0.575822  5.632956e-27
#                          Coarseness                              0.369848  1.598243e-31
#                          Complexity                              0.531626  4.437843e-28
#                          Contrast                                0.656482  1.050045e-24
#                          Strength                                0.383139  2.871160e-31
# wavelet-LHH   firstorder 10Percentile                            0.954255  2.498255e-08
#                          90Percentile                            0.956785  5.257279e-08
#                          Energy                                  0.628473  1.548052e-25
#                          Entropy                                 0.323328  2.216726e-32
#                          InterquartileRange                      0.940048  5.727677e-10
#                          Kurtosis                                0.483101  3.359702e-29
#                          Maximum                                 0.635562  2.486041e-25
#                          MeanAbsoluteDeviation                   0.954066  2.365184e-08
#                          Mean                                    0.651190  7.247684e-25
#                          Median                                  0.529291  3.900915e-28
#                          Minimum                                 0.829915  6.667038e-18
#                          Range                                   0.714209  8.226269e-23
#                          RobustMeanAbsoluteDeviation             0.943957  1.523347e-09
#                          RootMeanSquared                         0.960812  1.814308e-07
#                          Skewness                                0.849187  7.415534e-17
#                          TotalEnergy                             0.628473  1.548052e-25
#                          Uniformity                              0.295632  7.197767e-33
#                          Variance                                0.841753  2.855541e-17
#               glcm       Autocorrelation                         0.108248  8.069020e-36
#                          ClusterProminence                       0.987711  9.154608e-03
#                          ClusterShade                            0.684188  7.886790e-24
#                          ClusterTendency                         0.988077  1.105840e-02
#                          Contrast                                0.987601  8.648311e-03
#                          Correlation                             0.987710  9.146195e-03
#                          DifferenceAverage                       0.987603  8.657403e-03
#                          DifferenceEntropy                       0.942634  1.088956e-09
#                          DifferenceVariance                      0.939490  4.997922e-10
#                          Id                                      0.987605  8.664648e-03
#                          Idm                                     0.987604  8.663595e-03
#                          Idmn                                    0.828806  5.840645e-18
#                          Idn                                     0.970549  5.038946e-06
#                          Imc1                                    0.946311  2.802703e-09
#                          Imc2                                    0.940897  7.057900e-10
#                          InverseVariance                         0.987605  8.666627e-03
#                          JointAverage                            0.105507  7.371514e-36
#                          JointEnergy                             0.890499  3.075880e-14
#                          JointEntropy                            0.906622  5.014133e-13
#                          MCC                                     0.940449  6.320305e-10
#                          MaximumProbability                      0.793089  1.110064e-19
#                          SumAverage                              0.105507  7.371514e-36
#                          SumEntropy                              0.971533  7.268173e-06
#                          SumSquares                              0.325337  2.408608e-32
#               glrlm      GrayLevelNonUniformity                  0.758870  3.917035e-21
#                          GrayLevelNonUniformityNormalized        0.283178  4.390874e-33
#                          GrayLevelVariance                       0.286206  4.948461e-33
#                          HighGrayLevelRunEmphasis                0.050249  1.247975e-36
#                          LongRunEmphasis                         0.996291  6.768868e-01
#                          LongRunHighGrayLevelEmphasis            0.728586  2.704712e-22
#                          LongRunLowGrayLevelEmphasis             0.977288  7.110669e-05
#                          LowGrayLevelRunEmphasis                 0.080486  3.262952e-36
#                          RunEntropy                              0.989526  2.365443e-02
#                          RunLengthNonUniformity                  0.755968  2.999894e-21
#                          RunLengthNonUniformityNormalized        0.994579  3.320663e-01
#                          RunPercentage                           0.993989  2.491539e-01
#                          RunVariance                             0.994451  3.124511e-01
#                          ShortRunEmphasis                        0.993926  2.414871e-01
#                          ShortRunHighGrayLevelEmphasis           0.446406  5.405398e-30
#                          ShortRunLowGrayLevelEmphasis            0.792095  1.001574e-19
#               glszm      GrayLevelNonUniformity                  0.838593  1.921976e-17
#                          GrayLevelNonUniformityNormalized        0.819585  1.988152e-18
#                          GrayLevelVariance                       0.461635  1.140008e-29
#                          HighGrayLevelZoneEmphasis               0.855022  1.606745e-16
#                          LargeAreaEmphasis                       0.558945  2.084949e-27
#                          LargeAreaHighGrayLevelEmphasis          0.559524  2.156224e-27
#                          LargeAreaLowGrayLevelEmphasis           0.559096  2.103298e-27
#                          LowGrayLevelZoneEmphasis                0.987372  7.687389e-03
#                          SizeZoneNonUniformity                   0.828461  5.605204e-18
#                          SizeZoneNonUniformityNormalized         0.975749  3.771863e-05
#                          SmallAreaEmphasis                       0.920487  7.291698e-12
#                          SmallAreaHighGrayLevelEmphasis          0.976310  4.741445e-05
#                          SmallAreaLowGrayLevelEmphasis           0.958678  9.331013e-08
#                          ZoneEntropy                             0.978989  1.466913e-04
#                          ZonePercentage                          0.385256  3.154959e-31
#                          ZoneVariance                            0.538101  6.361719e-28
#               gldm       DependenceEntropy                       0.988808  1.620383e-02
#                          DependenceNonUniformity                 0.725864  2.151104e-22
#                          DependenceNonUniformityNormalized       0.990209  3.400604e-02
#                          DependenceVariance                      0.967045  1.434743e-06
#                          GrayLevelNonUniformity                  0.756993  3.295531e-21
#                          GrayLevelVariance                       0.307344  1.153080e-32
#                          HighGrayLevelEmphasis                   0.077683  2.981644e-36
#                          LargeDependenceEmphasis                 0.995558  5.138170e-01
#                          LargeDependenceHighGrayLevelEmphasis    0.636849  2.711415e-25
#                          LargeDependenceLowGrayLevelEmphasis     0.941534  8.266902e-10
#                          LowGrayLevelEmphasis                    0.158674  4.438437e-35
#                          SmallDependenceEmphasis                 0.791341  9.267229e-20
#                          SmallDependenceHighGrayLevelEmphasis    0.741908  8.511338e-22
#                          SmallDependenceLowGrayLevelEmphasis     0.775011  1.808657e-20
#               ngtdm      Busyness                                0.747051  1.341104e-21
#                          Coarseness                              0.393699  4.606302e-31
#                          Complexity                              0.183521  1.060187e-34
#                          Contrast                                0.731257  3.391608e-22
#                          Strength                                0.394464  4.767960e-31
# wavelet-LHL   firstorder 10Percentile                            0.819213  1.905338e-18
#                          90Percentile                            0.840286  2.374335e-17
#                          Energy                                  0.680767  6.104357e-24
#                          Entropy                                 0.805117  3.967434e-19
#                          InterquartileRange                      0.722608  1.639447e-22
#                          Kurtosis                                0.701767  3.045716e-23
#                          Maximum                                 0.925287  1.980836e-11
#                          MeanAbsoluteDeviation                   0.809035  6.083598e-19
#                          Mean                                    0.699497  2.549419e-23
#                          Median                                  0.624106  1.160373e-25
#                          Minimum                                 0.728148  2.606510e-22
#                          Range                                   0.816828  1.451981e-18
#                          RobustMeanAbsoluteDeviation             0.736793  5.452254e-22
#                          RootMeanSquared                         0.857837  2.352208e-16
#                          Skewness                                0.877332  3.865301e-15
#                          TotalEnergy                             0.680767  6.104357e-24
#                          Uniformity                              0.775668  1.928167e-20
#                          Variance                                0.483735  3.470602e-29
#               glcm       Autocorrelation                         0.454591  8.055742e-30
#                          ClusterProminence                       0.226949  5.120490e-34
#                          ClusterShade                            0.483264  3.387774e-29
#                          ClusterTendency                         0.350258  6.860819e-32
#                          Contrast                                0.421182  1.626783e-30
#                          Correlation                             0.994474  3.159424e-01
#                          DifferenceAverage                       0.709858  5.790043e-23
#                          DifferenceEntropy                       0.793103  1.111618e-19
#                          DifferenceVariance                      0.552053  1.401425e-27
#                          Id                                      0.908134  6.623787e-13
#                          Idm                                     0.864549  5.967822e-16
#                          Idmn                                    0.902799  2.514741e-13
#                          Idn                                     0.956246  4.477513e-08
#                          Imc1                                    0.928145  3.665429e-11
#                          Imc2                                    0.965029  7.191883e-07
#                          InverseVariance                         0.967538  1.704491e-06
#                          JointAverage                            0.711710  6.720285e-23
#                          JointEnergy                             0.852070  1.083653e-16
#                          JointEntropy                            0.802976  3.149299e-19
#                          MCC                                     0.981126  3.774193e-04
#                          MaximumProbability                      0.856966  2.089407e-16
#                          SumAverage                              0.711710  6.720285e-23
#                          SumEntropy                              0.834087  1.103567e-17
#                          SumSquares                              0.341873  4.807044e-32
#               glrlm      GrayLevelNonUniformity                  0.750771  1.871316e-21
#                          GrayLevelNonUniformityNormalized        0.849796  8.031157e-17
#                          GrayLevelVariance                       0.527440  3.523372e-28
#                          HighGrayLevelRunEmphasis                0.452153  7.149719e-30
#                          LongRunEmphasis                         0.990588  4.165279e-02
#                          LongRunHighGrayLevelEmphasis            0.490106  4.817405e-29
#                          LongRunLowGrayLevelEmphasis             0.891061  3.373290e-14
#                          LowGrayLevelRunEmphasis                 0.867300  8.824126e-16
#                          RunEntropy                              0.996844  7.991737e-01
#                          RunLengthNonUniformity                  0.763248  5.885609e-21
#                          RunLengthNonUniformityNormalized        0.899031  1.296750e-13
#                          RunPercentage                           0.936261  2.305627e-10
#                          RunVariance                             0.985906  3.661626e-03
#                          ShortRunEmphasis                        0.960798  1.806109e-07
#                          ShortRunHighGrayLevelEmphasis           0.471726  1.886542e-29
#                          ShortRunLowGrayLevelEmphasis            0.875875  3.102591e-15
#               glszm      GrayLevelNonUniformity                  0.490945  5.031161e-29
#                          GrayLevelNonUniformityNormalized        0.991444  6.583264e-02
#                          GrayLevelVariance                       0.582309  8.322003e-27
#                          HighGrayLevelZoneEmphasis               0.488920  4.531041e-29
#                          LargeAreaEmphasis                       0.310798  1.326632e-32
#                          LargeAreaHighGrayLevelEmphasis          0.481415  3.082294e-29
#                          LargeAreaLowGrayLevelEmphasis           0.175094  7.872133e-35
#                          LowGrayLevelZoneEmphasis                0.835355  1.288719e-17
# ...
#                                      GrayLevelNonUniformity                0.055841  0.945699
#                                      GrayLevelVariance                     0.414357  0.661129
#                                      HighGrayLevelEmphasis                 0.547451  0.578979
#                                      LargeDependenceEmphasis               0.001657  0.998345
#                                      LargeDependenceHighGrayLevelEmphasis  1.458338  0.234209
#                                      LargeDependenceLowGrayLevelEmphasis   0.039437  0.961335
#                                      LowGrayLevelEmphasis                  0.293235  0.746053
#                                      SmallDependenceEmphasis               0.053344  0.948062
#                                      SmallDependenceHighGrayLevelEmphasis  0.000461  0.999539
#                                      SmallDependenceLowGrayLevelEmphasis   0.206951  0.813171
#                           ngtdm      Busyness                              0.723800  0.485721
#                                      Coarseness                            1.378613  0.253463
#                                      Complexity                            1.079330  0.341092
#                                      Contrast                              0.514443  0.598342
#                                      Strength                              2.302883  0.101673
# squareroot                firstorder 10Percentile                          0.948669  0.388374
#                                      90Percentile                          0.007749  0.992281
#                                      Energy                                0.025067  0.975246
#                                      Entropy                               2.125251  0.121134
#                                      InterquartileRange                    0.666077  0.514451
#                                      Kurtosis                              1.434203  0.239877
#                                      Maximum                               0.409592  0.664279
#                                      MeanAbsoluteDeviation                 0.628690  0.533967
#                                      Mean                                  0.105944  0.899507
#                                      Median                                0.317340  0.728318
#                                      Minimum                               0.693102  0.500793
#                                      Range                                 0.487718  0.614495
#                                      RobustMeanAbsoluteDeviation           0.658629  0.518281
#                                      RootMeanSquared                       0.766501  0.465512
#                                      Skewness                              1.250886  0.287687
#                                      TotalEnergy                           0.025067  0.975246
#                                      Uniformity                            3.127378  0.045214
#                                      Variance                              0.111142  0.894847
#                           glcm       Autocorrelation                       0.777641  0.460380
#                                      ClusterProminence                     0.055506  0.946016
#                                      ClusterShade                          0.334942  0.715637
#                                      ClusterTendency                       0.059029  0.942690
#                                      Contrast                              1.075288  0.342465
#                                      Correlation                           0.161548  0.850897
#                                      DifferenceAverage                     2.197856  0.112763
#                                      DifferenceEntropy                     2.855662  0.059027
#                                      DifferenceVariance                    1.016989  0.362882
#                                      Id                                    3.430843  0.033589
#                                      Idm                                   3.218054  0.041370
#                                      Idmn                                  1.305055  0.272638
#                                      Idn                                   2.494937  0.084152
#                                      Imc1                                  1.670879  0.189766
#                                      Imc2                                  1.004806  0.367301
#                                      InverseVariance                       5.394663  0.004976
#                                      JointAverage                          0.340655  0.711569
#                                      JointEnergy                           3.831274  0.022713
#                                      JointEntropy                          2.484602  0.085012
#                                      MCC                                   0.355017  0.701445
#                                      MaximumProbability                    3.188725  0.042576
#                                      SumAverage                            0.340655  0.711569
#                                      SumEntropy                            2.363688  0.095761
#                                      SumSquares                            0.088151  0.915645
#                           glrlm      GrayLevelNonUniformity                1.768908  0.172230
#                                      GrayLevelNonUniformityNormalized      0.797829  0.451225
#                                      GrayLevelVariance                     0.063320  0.938656
#                                      HighGrayLevelRunEmphasis              1.175438  0.310051
#                                      LongRunEmphasis                       2.010468  0.135663
#                                      LongRunHighGrayLevelEmphasis          1.656860  0.192416
#                                      LongRunLowGrayLevelEmphasis           2.832399  0.060391
#                                      LowGrayLevelRunEmphasis               0.279934  0.756024
#                                      RunEntropy                            3.169322  0.043393
#                                      RunLengthNonUniformity                0.388660  0.678293
#                                      RunLengthNonUniformityNormalized      2.072441  0.127613
#                                      RunPercentage                         3.578988  0.029059
#                                      RunVariance                           2.038164  0.132004
#                                      ShortRunEmphasis                      2.100227  0.124162
#                                      ShortRunHighGrayLevelEmphasis         1.634491  0.196723
#                                      ShortRunLowGrayLevelEmphasis          0.337625  0.713724
#                           glszm      GrayLevelNonUniformity                0.086295  0.917346
#                                      GrayLevelNonUniformityNormalized      0.545963  0.579838
#                                      GrayLevelVariance                     1.308551  0.271695
#                                      HighGrayLevelZoneEmphasis             1.366977  0.256403
#                                      LargeAreaEmphasis                     0.262107  0.769598
#                                      LargeAreaHighGrayLevelEmphasis        0.117842  0.888876
#                                      LargeAreaLowGrayLevelEmphasis         0.447029  0.639936
#                                      LowGrayLevelZoneEmphasis              0.016968  0.983176
#                                      SizeZoneNonUniformity                 0.039164  0.961598
#                                      SizeZoneNonUniformityNormalized       1.010340  0.365287
#                                      SmallAreaEmphasis                     0.829233  0.437347
#                                      SmallAreaHighGrayLevelEmphasis        0.875853  0.417532
#                                      SmallAreaLowGrayLevelEmphasis         0.001196  0.998805
#                                      ZoneEntropy                           0.426994  0.652849
#                                      ZonePercentage                        0.941586  0.391118
#                                      ZoneVariance                          0.260962  0.770479
#                           gldm       DependenceEntropy                     2.979246  0.052284
#                                      DependenceNonUniformity               1.275152  0.280845
#                                      DependenceNonUniformityNormalized     3.946277  0.020302
#                                      DependenceVariance                    0.314400  0.730459
#                                      GrayLevelNonUniformity                0.010045  0.990006
#                                      GrayLevelVariance                     0.134613  0.874105
#                                      HighGrayLevelEmphasis                 0.713145  0.490900
#                                      LargeDependenceEmphasis               3.908228  0.021070
#                                      LargeDependenceHighGrayLevelEmphasis  0.758949  0.469023
#                                      LargeDependenceLowGrayLevelEmphasis   0.710648  0.492122
#                                      LowGrayLevelEmphasis                  0.137620  0.871483
#                                      SmallDependenceEmphasis               1.423613  0.242407
#                                      SmallDependenceHighGrayLevelEmphasis  1.172480  0.310963
#                                      SmallDependenceLowGrayLevelEmphasis   0.320606  0.725948
#                           ngtdm      Busyness                              1.559713  0.211836
#                                      Coarseness                            0.126402  0.881306
#                                      Complexity                            1.562935  0.211161
#                                      Contrast                              1.509848  0.222559
#                                      Strength                              0.446413  0.640329
# [2024-02-24 04:38:42,332-INFO] (preliminary_feature_filtering) Number of features dropped by using T-test or ANOVA for first feature set: 878
# [2024-02-24 04:38:42,333-INFO] (preliminary_feature_filtering) Final remaining features: 51
# [2024-02-24 04:38:42,361-INFO] (sup-featselect) Multi-class target encountered.
# [2024-02-24 04:38:42,381-INFO] (sup-featselect) ENET selected 26 features.
# [2024-02-24 04:38:42,382-DEBUG] (sup-featselect) Selected features are:
#  Index(['exponential__firstorder__Kurtosis',
#        'exponential__firstorder__Skewness',
#        'exponential__glcm__ClusterProminence',
#        'exponential__glcm__ClusterShade',
#        'exponential__glszm__SizeZoneNonUniformityNormalized',
#        'exponential__ngtdm__Strength',
#        'lbp-3D-k__glszm__GrayLevelNonUniformityNormalized',
#        'lbp-3D-k__glszm__SmallAreaLowGrayLevelEmphasis',
#        'lbp-3D-k__glszm__ZoneEntropy', 'lbp-3D-k__glszm__ZonePercentage',
#        'lbp-3D-k__gldm__HighGrayLevelEmphasis', 'lbp-3D-m1__glcm__Correlation',
#        'lbp-3D-m1__glszm__LowGrayLevelZoneEmphasis',
#        'lbp-3D-m1__glszm__SmallAreaLowGrayLevelEmphasis',
#        'logarithm__glcm__Id', 'logarithm__glcm__InverseVariance',
#        'logarithm__glcm__MaximumProbability',
#        'logarithm__gldm__DependenceNonUniformityNormalized',
#        'square__firstorder__10Percentile', 'square__glszm__GrayLevelVariance',
#        'squareroot__firstorder__Uniformity', 'squareroot__glcm__Idm',
#        'squareroot__glcm__MaximumProbability', 'squareroot__glrlm__RunEntropy',
#        'squareroot__glrlm__RunPercentage',
#        'squareroot__gldm__DependenceNonUniformityNormalized'],
#       dtype='object')
# [2024-02-24 04:38:42,382-INFO] (sup-featselect) Features dropped by ENet 25
# [2024-02-24 04:38:42,391-INFO] (model-building) ---------------------------------Fitting for Support Vector Machine---------------------------------
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [2024-02-24 04:38:49,613-INFO] (model-building) Train score: 0.71959
# [2024-02-24 04:38:49,614-DEBUG] (model-building) Individual internal test scores: [0.62048904 0.62228875 0.61773834 0.62154484]
# [2024-02-24 04:38:49,614-INFO] (model-building) Mean internal test score: 0.62052
# [2024-02-24 04:38:49,614-INFO] (model-building) Best internal test score: 0.62229
# [2024-02-24 04:38:49,614-INFO] (model-building) ----------------------------------Done for Support Vector Machine-----------------------------------
# [2024-02-24 04:38:49,614-INFO] (model-building) ------------------------------Fitting for Support Vector Machine (rbf)------------------------------
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [2024-02-24 04:38:50,180-INFO] (model-building) Train score: 0.80409
# [2024-02-24 04:38:50,180-DEBUG] (model-building) Individual internal test scores: [0.61765009 0.618218   0.61622459 0.61957877 0.62051115 0.62358602
#  0.62190219 0.62126772 0.58478925 0.59002875 0.60227884 0.59278882
#  0.55889164 0.56296044 0.56246854 0.55819969]
# [2024-02-24 04:38:50,180-INFO] (model-building) Mean internal test score: 0.59821
# [2024-02-24 04:38:50,180-INFO] (model-building) Best internal test score: 0.62359
# [2024-02-24 04:38:50,180-INFO] (model-building) -------------------------------Done for Support Vector Machine (rbf)--------------------------------
# [2024-02-24 04:38:50,180-INFO] (model-building) ----------------------------------Fitting for Logistic Regression-----------------------------------
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [2024-02-24 04:38:53,375-INFO] (model-building) Train score: 0.71250
# [2024-02-24 04:38:53,376-DEBUG] (model-building) Individual internal test scores: [0.62314795 0.60861601 0.61171683 0.61197164 0.60886528 0.60864211
#  0.60838718 0.60854591]
# [2024-02-24 04:38:53,376-INFO] (model-building) Mean internal test score: 0.61124
# [2024-02-24 04:38:53,376-INFO] (model-building) Best internal test score: 0.62315
# [2024-02-24 04:38:53,376-INFO] (model-building) ------------------------------------Done for Logistic Regression------------------------------------
# [2024-02-24 04:38:53,377-INFO] (model-building) -------------------------------------Fitting for Random Forest--------------------------------------
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [2024-02-24 04:38:55,788-INFO] (model-building) Train score: 0.95472
# [2024-02-24 04:38:55,789-DEBUG] (model-building) Individual internal test scores: [0.5583514  0.51888341 0.54839426 0.53175447 0.54975238 0.5632009
#  0.55711516 0.5612059  0.54578173 0.54533299 0.54718395 0.55797849
#  0.57917109 0.54981743 0.5259083  0.53185814 0.576256   0.54301723
#  0.54913704 0.56116835 0.58446901 0.55451273 0.54838059 0.55653833
#  0.54442084 0.5451113  0.55095204 0.53526919 0.52256447 0.54784825
#  0.53858277 0.55859549]
# [2024-02-24 04:38:55,789-INFO] (model-building) Mean internal test score: 0.54964
# [2024-02-24 04:38:55,789-INFO] (model-building) Best internal test score: 0.58447
# [2024-02-24 04:38:55,789-INFO] (model-building) ---------------------------------------Done for Random Forest---------------------------------------
# [2024-02-24 04:38:55,789-INFO] (model-building) ------------------------------------------Fitting for KNN-------------------------------------------
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [2024-02-24 04:38:55,828-INFO] (model-building) Train score: 0.78527
# [2024-02-24 04:38:55,829-DEBUG] (model-building) Individual internal test scores: [0.55558449 0.58708246 0.57526495 0.57347249]
# [2024-02-24 04:38:55,829-INFO] (model-building) Mean internal test score: 0.57285
# [2024-02-24 04:38:55,829-INFO] (model-building) Best internal test score: 0.58708
# [2024-02-24 04:38:55,829-INFO] (model-building) --------------------------------------------Done for KNN--------------------------------------------

# %% [markdown]
# ## Run K-fold cross validation

# %%
from feature_robustness_analysis.io import prepend_index_level

# makesure random seed is reset
np.random.seed(None)    


# Mute the logger because its too noisy
MNTSLogger.set_global_verbosity(False)
MNTSLogger.set_global_log_level('info')

# Setup performance metric
# scoring_func = partial(top_k_accuracy_score_, k=1)

# * Perform N times K-fold
N = global_config['N']
K = global_config['K']
preds = []
trials = []
final_features = []
fit_failed = []
show_sub_progress = False
for n in auto.trange(N):
    # Because some patients has more than one lesion, the K-fold are constructed by 
    # splitting patients instead of splitting lesions to avoid data leakage.
    unique_patients = y.index.get_level_values(0).unique()
    unique_y = y.droplevel(1).index.duplicated(keep='first')
    unique_y = y[~unique_y]
    
    # K-fold splitter
    kfold_splitter = StratifiedKFold(n_splits=K, shuffle=True)
    
    # Prepare the results to be recorded per trial
    trial_row = pd.Series(
        index=pd.MultiIndex.from_product(
            [list(X_R0.keys()), 
             list(range(K)),
             list(clf_card.keys()), 
             tuple(['Performance']), 
             tuple(['R00'] + rot_degs)], 
            names=['Feature Category', 'Fold #', 'Model', 'Pocket', 'Rotations']
        ),
        name=f'Trial-{n:03d}'
    )
    # Train and test for each feature group ('All', 'WD', 'nWD')
    for fold_number, (train_set, test_set) in enumerate(kfold_splitter.split(unique_patients, unique_y)):
        # configure X and y
        train_set_patients = unique_patients[train_set]
        test_set_patients = unique_patients[test_set]
        
        # Loop feature group
        for feat_group in X_R0:
            # * Get preliminarily selected features (computed outside this loop)
            pre_selected_features = prelim_features[feat_group]
            
            _X_n_train = X_R0[feat_group][train_set_patients].loc[pre_selected_features].copy()
            _y_n_train = y[train_set_patients].copy()
            _X_n_test = X_R0[feat_group][test_set_patients].loc[pre_selected_features].copy()
            _y_n_test = y[test_set_patients].copy()
            
            # * Perform supervised feature selection and normalization
            _X_n_train, _X_n_test, chosen_feats = normalize_n_feature_selection(
                _X_n_train, 
                _y_n_train.to_frame(), 
                _X_n_test
            )
            _features_row = pd.Series(chosen_feats.to_list(), name=(n, fold_number, feat_group)) 
            final_features.append(_features_row) # store this
            
            # if there are too few features remained, throw a warning
            if _X_n_train.shape[0] <5:
                warnings.warn(f"The current loop {n}, fold {fold_number} of {feat_group} has very few features ({_X_n_train.shape[0]}) survived.")
            
            #! Grid search for optimized parameters
            if switch['AddGridSearch']:
                clf = sklearn.pipeline.Pipeline([
                    ('standardization', normalizer_cls()),
                    ('classification', 'passthrough')
                ]) 
                _, __, ___, be = cv_grid_search(
                    _X_n_train.T, _y_n_train.astype('int'),
                    param_grid_dict=clf_card,
                    scoring=scoring_func_name,
                    clf=clf, 
                    refit=True, 
                    n_jobs=10
                )
            else:
                be = best_estimators[feat_group]
            
            # * Loop for each ML model
            for model_name, model in be.items():
                # Training with R0 features again
                _model = sklearn.base.clone(model)
                
                with warnings.catch_warnings():
                    warnings.filterwarnings('error', category=sklearn.exceptions.ConvergenceWarning)
                    warnings.filterwarnings('ignore', category=FutureWarning)
                    try:
                        if switch['AddSMOTE']:
                            #! SMOTE
                            smote_sampler = SMOTE()
                            X_smote, y_smote = smote_sampler.fit_resample(_X_n_train.T, _y_n_train) # X.T: (n_samples, n_features)
                            X_smote = X_smote.T # X_smote: (n_features, n_samples)
                            y_smote = pd.DataFrame(y_smote, index=X_smote.columns)
                            _model.fit(X_smote.T, y_smote)
                        else:
                            #! No SMOTE
                            _model.fit(_X_n_train.T, _y_n_train.to_frame())
                    except sklearn.exceptions.ConvergenceWarning as w:
                        # record fail to fit
                        failed2fit = {
                            'Trial #': n, 
                            'Fold #': fold_number, 
                            'Model': model_name, 
                            'Feature Category': feat_group
                        }
                        fit_failed.append(failed2fit)
                        print(f"Fail to fit: {failed2fit}")
                        continue
                    
                
                # * Test with R0 features
                _pred = _model.predict(_X_n_test.T)
                _pred_proba = _model.predict_proba(_X_n_test.T)
                _pred_row = pd.DataFrame(
                    _pred_proba, index=_y_n_test.index,
                    columns=pd.MultiIndex.from_tuples([
                        (n, 'predict_proba', f"Fold {fold_number}", feat_group, model_name, 'R00', a) for a in range(_pred_proba.shape[1])
                    ])
                )
                preds.append(_pred_row)
                # also get predict() because predict() and predict_proba() can give diff results
                # based on what is said on sklearn. 
                _pred_row = pd.DataFrame(
                    _pred, index=_y_n_test.index,
                    columns=pd.MultiIndex.from_tuples([
                        (n, 'predict', f"Fold {fold_number}", feat_group, model_name, 'R00', -1) # Class -1 means result from `predict()`, it is usually integer representing class
                    ])
                )
                preds.append(_pred_row)
                
                # * Run also for training set
                _pred_train = _model.predict(_X_n_train.T)
                _pred_row = pd.DataFrame(
                    _pred_train, index=_y_n_train.index, 
                    columns=pd.MultiIndex.from_tuples([
                        (n, 'train', f"Fold {fold_number}", feat_group, model_name, 'R00', -1) # Class -1 means result from `predict()`, it is usually integer representing class
                    ])
                )
                preds.append(_pred_row)
                
                _score = scoring_func(_y_n_test, _pred)
                trial_row[feat_group, fold_number, model_name, 'Performance', 'R00'] = _score
                # Test with rotated features
                for rot in rot_degs:
                    _X_rot_train = X_all_rest[rot][_X_n_train.columns].loc[chosen_feats]
                    _X_rot_test = X_all_rest[rot][_X_n_test.columns].loc[chosen_feats]

                    if switch['UpdateStandardization']:
                        # ! update feature normalization parameters for rotated features using the training set
                        test_norm = normalizer_cls()
                        test_norm.fit(_X_rot_train.T) # Fit using training set mean/var
                        _X_rot_test_normed = test_norm.transform(_X_rot_test.T).T
                        _pred = _model[1].predict(_X_rot_test_normed.T)
                        _pred_proba = _model[1].predict_proba(_X_rot_test_normed.T)
                        _pred_train = _model[1].predict(test_norm.fit_transform(_X_rot_train.T))
                    else:
                        # ! no feature normalization update, directly use trained parameters
                        _pred = _model.predict(_X_rot_test.T)
                        _pred_proba = _model.predict_proba(_X_rot_test.T)
                        _pred_train = _model.predict(_X_rot_train.T)
                        
                    #* build row with header [num_trial, pred_func, num_fold, feat_group, model_name, rotation, class]
                    _pred_row = pd.DataFrame(
                        _pred_proba,
                        index=_y_n_test.index,
                        columns=pd.MultiIndex.from_tuples([
                            (n, 'predict_proba', f"Fold {fold_number}", feat_group, model_name, rot, a) for a in range(_pred_proba.shape[1])
                        ])
                    )
                    preds.append(_pred_row)
                    _pred_row = pd.DataFrame(
                        _pred,
                        index=_y_n_test.index,
                        columns=pd.MultiIndex.from_tuples([
                            (n, 'predict', f"Fold {fold_number}", feat_group, model_name, rot, -1)
                        ])
                    )
                    preds.append(_pred_row)
                    _pred_row = pd.DataFrame(
                        _pred_train,
                        index=_y_n_train.index,
                        columns=pd.MultiIndex.from_tuples([
                            (n, 'train', f"Fold {fold_number}", feat_group, model_name, rot, -1)
                        ])
                    )
                    preds.append(_pred_row)
                    _score = scoring_func(_y_n_test, _pred)
                    trial_row[feat_group, fold_number, model_name, 'Performance', rot] = _score
    trials.append(trial_row)
    
# Unmute the logger
MNTSLogger.set_global_verbosity(True)

# Build dataframes
df_preds = pd.concat(preds, axis=1)
df_preds.columns.names=['Iteration # (n)', 'Pred Func', 'Fold #', 'Feature Category', 'Classifier', 'Rotation', 'Classes']
df_preds.sort_index(axis=1, level=0, inplace=True)
df_preds.sort_index(axis=0, level=0, inplace=True)
df_features = pd.concat(final_features, axis=1)
df_features.columns.name = ('Iteration # (n)', 'Fold #', 'Feature Group')
df_features.fillna("", inplace=True)
df_trials = pd.concat(trials, axis=1).T
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
# Plot how many of those runs has been unsuccessful
df_fit_failed = {}
for v in fit_failed:
    idx = tuple(v.values())
    df_fit_failed[idx] = True
if len(df_fit_failed) > 0:
    df_fit_failed = pd.Series(df_fit_failed, name='Not converged')
    df_fit_failed.index.names = v.keys()
    mdprint("## Model failed to converge ")
    display(df_fit_failed.to_frame())
    display(df_fit_failed.groupby(["Feature Category", "Model"]).count().to_frame())
else:
    print("All fits were sucessful.")
# Out:
# All fits were sucessful.

# %%
# Save output as excels
output_dir = data_root
excel_dir = output_dir / "n_k-fold_cv_results_3classes.xlsx"

# Save to excel, this does not always work becuase of the huge size of the tables, so is disabled now
# with pd.ExcelWriter(excel_dir, mode='w', engine='openpyxl') as excel_writer:
#     df_preds.fillna("train").T.to_excel(excel_writer, sheet_name='Predictions')
#     df_features.fillna("").to_excel(excel_writer, sheet_name="Selected Features")wwd
#     df_trials.fillna("").to_excel(excel_writer, sheet_name="Performances")

# Also save to HDF, this is quick and more reliable than excel.
with pd.HDFStore(excel_dir.with_suffix('.h5')) as hdf_file:
    df_preds.fillna("train").T.to_hdf(hdf_file, key = 'Predictions')
    df_features.fillna("").to_hdf(hdf_file    , key = "Selected Features")
    df_trials.fillna("").to_hdf(hdf_file      , key = "Performances")

# %% [markdown]
# # Selected features analysis
#
# Note that all other analysis were conducted in `3_performance_analysis.ipynb`

# %%
df_features.columns.names = ['Trial #', 'Fold #', 'Feature Category']
for feat_gp in df_features.columns.get_level_values('Feature Category').unique():
    mdprint(f"### {feat_gp}")
    _df = df_features.xs(feat_gp, level='Feature Category', axis=1)
    
    # count frequency, note that each feature is unique in each trial (i.e., in each column)
    feat_list = _df.values.flatten().tolist()
    union_feats = set(feat_list)
    counts = pd.Series({feat_name: feat_list.count(feat_name) for feat_name in feat_list}, name="Counts")
    selected_chance = counts / float(_df.shape[1])
    selected_chance = selected_chance.apply(lambda x: f"{x * 100:.02f}%")
    selected_chance.name = 'Percentage'
    counts = pd.concat([counts, selected_chance],axis=1)
    counts.drop('', inplace=True)
    mdprint("#### Feature counts")
    display(counts.sort_values(by='Counts', ascending=False).iloc[:50])
    
    # average number of features
    s = _df.apply(lambda x: (x != '').sum())
    s.name = 'Number of selected features'
    mdprint("#### Number of fetures")
    display(s.to_frame())
    
    mdprint(f"Average nubmer of feature selected: {s.mean()}")
# Out:
# ### WD
# #### Feature counts
#                                                     Counts Percentage
# (wavelet-LLH, glcm, ClusterTendency)                   250    100.00%
# (wavelet-HHL, glcm, ClusterTendency)                   250    100.00%
# (wavelet-LHL, glszm, LowGrayLevelZoneEmphasis)         250    100.00%
# (wavelet-LHH, glrlm, RunVariance)                      249     99.60%
# (wavelet-HLH, glcm, MCC)                               249     99.60%
# (wavelet-LLH, glszm, SmallAreaLowGrayLevelEmpha...     248     99.20%
# (wavelet-HHH, glrlm, ShortRunLowGrayLevelEmphasis)     247     98.80%
# (wavelet-LLH, glrlm, ShortRunEmphasis)                 247     98.80%
# (wavelet-LHH, firstorder, InterquartileRange)          247     98.80%
# (wavelet-LLH, firstorder, Minimum)                     242     96.80%
# (wavelet-HLL, gldm, LargeDependenceEmphasis)           239     95.60%
# (wavelet-HLL, firstorder, InterquartileRange)          231     92.40%
# (wavelet-HHL, glcm, Contrast)                          221     88.40%
# (wavelet-LHH, ngtdm, Contrast)                         216     86.40%
# (wavelet-LHL, gldm, LargeDependenceEmphasis)           212     84.80%
# (wavelet-LLH, glrlm, ShortRunHighGrayLevelEmpha...     211     84.40%
# (wavelet-HHL, glcm, ClusterProminence)                 199     79.60%
# (wavelet-HLH, glszm, GrayLevelVariance)                199     79.60%
# (wavelet-HHL, firstorder, Variance)                    196     78.40%
# (wavelet-LHH, glcm, Idn)                               182     72.80%
# (wavelet-HLH, firstorder, InterquartileRange)          177     70.80%
# (wavelet-HLH, glrlm, LowGrayLevelRunEmphasis)          172     68.80%
# (wavelet-HLH, glrlm, LongRunHighGrayLevelEmphasis)     156     62.40%
# (wavelet-HHL, firstorder, 90Percentile)                144     57.60%
# (wavelet-HHH, gldm, LargeDependenceHighGrayLeve...     144     57.60%
# (wavelet-LHH, glrlm, ShortRunLowGrayLevelEmphasis)     142     56.80%
# (wavelet-LHH, gldm, LowGrayLevelEmphasis)              141     56.40%
# (wavelet-HLH, ngtdm, Contrast)                         134     53.60%
# (wavelet-LHH, glrlm, ShortRunHighGrayLevelEmpha...     130     52.00%
# (wavelet-LLH, glrlm, HighGrayLevelRunEmphasis)         129     51.60%
# (wavelet-HHL, firstorder, 10Percentile)                101     40.40%
# (wavelet-HLH, ngtdm, Complexity)                        60     24.00%
# #### Number of fetures
#                 Number of selected features
# Trial # Fold #
# 0       0                                25
#         1                                21
#         2                                25
#         3                                25
#         4                                28
# ...                                     ...
# 49      0                                24
#         1                                26
#         2                                26
#         3                                27
#         4                                25
#
# [250 rows x 1 columns]
# Average nubmer of feature selected: 24.86
# ### nWD
# #### Feature counts
#                                                     Counts Percentage
# (lbp-3D-k, glszm, ZonePercentage)                      250    100.00%
# (exponential, glszm, SizeZoneNonUniformityNorma...     250    100.00%
# (lbp-3D-m1, glcm, Correlation)                         250    100.00%
# (exponential, firstorder, Kurtosis)                    247     98.80%
# (exponential, ngtdm, Strength)                         247     98.80%
# (squareroot, gldm, DependenceNonUniformityNorma...     246     98.40%
# (exponential, glcm, ClusterShade)                      246     98.40%
# (square, firstorder, 10Percentile)                     246     98.40%
# (logarithm, glcm, InverseVariance)                     246     98.40%
# (lbp-3D-k, glszm, SmallAreaLowGrayLevelEmphasis)       242     96.80%
# (lbp-3D-m1, glszm, SmallAreaLowGrayLevelEmphasis)      236     94.40%
# (squareroot, firstorder, Uniformity)                   232     92.80%
# (squareroot, glcm, MaximumProbability)                 229     91.60%
# (exponential, glcm, ClusterProminence)                 218     87.20%
# (logarithm, gldm, DependenceNonUniformityNormal...     215     86.00%
# (squareroot, glrlm, RunEntropy)                        212     84.80%
# (logarithm, glcm, MaximumProbability)                  199     79.60%
# (square, glszm, GrayLevelVariance)                     195     78.00%
# (exponential, firstorder, Skewness)                    184     73.60%
# (lbp-3D-k, glszm, ZoneEntropy)                         172     68.80%
# (lbp-3D-m1, glszm, LowGrayLevelZoneEmphasis)           167     66.80%
# (lbp-3D-k, glszm, GrayLevelNonUniformityNormali...     159     63.60%
# (lbp-3D-k, gldm, HighGrayLevelEmphasis)                156     62.40%
# (squareroot, glrlm, RunPercentage)                      99     39.60%
# (squareroot, glcm, Idm)                                 87     34.80%
# (logarithm, glcm, Id)                                   50     20.00%
# #### Number of fetures
#                 Number of selected features
# Trial # Fold #
# 0       0                                21
#         1                                20
#         2                                21
#         3                                22
#         4                                23
# ...                                     ...
# 49      0                                22
#         1                                22
#         2                                17
#         3                                21
#         4                                24
#
# [250 rows x 1 columns]
# Average nubmer of feature selected: 21.12
